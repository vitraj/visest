# %%
import os
import yaml
import multiprocessing as mp
import time
import tools21cm as t2c
from tqdm import tqdm
import astropy.units as u
import astropy.constants as cst
import cupy as cp
import numpy as np
import itertools

import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"


def filter_baselines(baselines, visibilities, u_freq, v_freq):
    """Filters baselines and corresponding visibilities based on the range of
    frequencies. This is so that the baselines outside the frequency range of
    the fft image are removed.

    Parameters:
    baselines (list): List of baseline coordinates.
    visibilities (list): List of corresponding visibilities.
    u_freq (list): List of u frequencies.
    v_freq (list): List of v frequencies.

    Returns:
    filtered_baselines (ndarray): Numpy array of filtered baseline coordinates.
    filtered_visibilities (ndarray): Numpy array of filtered visibilities.
    """
    filtered_baselines = []
    filtered_visibilities = []

    for baseline, visibility in zip(baselines, visibilities):
        x, y = baseline
        # Check if baseline coordinates are within the range of frequencies
        if (np.min(u_freq) <= x <= np.max(u_freq)) and (
            np.min(v_freq) <= y <= np.max(v_freq)
        ):
            filtered_baselines.append(baseline)
            filtered_visibilities.append(visibility)
    return np.array(filtered_baselines), np.array(filtered_visibilities)


def filter_baselines_cupy(baselines, visibilities, u_freq, v_freq):
    """Filters baselines and corresponding visibilities based on the range of
    frequencies. This is so that the baselines outside the frequency range of
    the fft image are removed.

    Parameters:
    baselines (ndarray): Numpy array of baseline coordinates.
    visibilities (ndarray): Numpy array of corresponding visibilities.
    u_freq (ndarray): Numpy array of u frequencies.
    v_freq (ndarray): Numpy array of v frequencies.

    Returns:
    filtered_baselines (ndarray): CuPy array of filtered baseline coordinates.
    filtered_visibilities (ndarray): CuPy array of filtered visibilities.
    """
    # Convert inputs to CuPy arrays
    baselines_cp = cp.array(baselines)
    visibilities_cp = cp.array(visibilities)
    u_freq_cp = cp.array(u_freq)
    v_freq_cp = cp.array(v_freq)
    
    # Find the min and max frequencies
    u_min, u_max = cp.min(u_freq_cp), cp.max(u_freq_cp)
    v_min, v_max = cp.min(v_freq_cp), cp.max(v_freq_cp)
    
    # Filter baselines based on frequency range
    x = baselines_cp[:, 0]
    y = baselines_cp[:, 1]
    mask = (u_min <= x) & (x <= u_max) & (v_min <= y) & (y <= v_max)
    
    # Apply mask to baselines and visibilities
    filtered_baselines = baselines_cp[mask]
    filtered_visibilities = visibilities_cp[mask]
    
    return filtered_baselines, filtered_visibilities


def read_config(input_path):
    with open(input_path) as stream:
        try:
            config = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    return config


def plot(bare_estimator, ell_mean, var_squared, file_path, img_dpi):
    # Plot the results
    fig, axs = plt.subplots(1, 2, figsize=(17, 5))

    axs[0].errorbar(ell_mean, bare_estimator, np.sqrt(var_squared),
        color="#1f77b4",
        label="Gaussian primary beam",
        elinewidth=0.75,
        capsize=4,
        fmt="o",
        markersize=3)
    axs[0].plot(ell_mean, 5.13 * 1e-4 * (1000 / ell_mean) ** 2.34,
        color="k",
        label="Model",
        alpha=0.75)
    axs[0].set_yscale("log")
    #axs[0].set_ylim(5.13 * 1e-4 * (1000 / ell_mean[-1]) ** 2.34, 5.13 * 1e-4 * (1000 / ell_mean[0]) ** 2.34)
    axs[0].grid()
    axs[0].set_xlabel(r"$\ell$", fontsize=14)
    axs[0].set_ylabel(r"$C_{\ell}$ $[K^2]$", fontsize=14)
    axs[0].legend()

    axs[1].errorbar(ell_mean, ell_mean * (ell_mean + 1) * bare_estimator / (2 * np.pi), ell_mean * (ell_mean + 1) * np.sqrt(var_squared) / (2 * np.pi),
        color="#1f77b4",
        label="Gaussian primary beam",
        elinewidth=0.75,
        capsize=4,
        fmt="o",
        markersize=3)
    axs[1].plot(ell_mean, ell_mean * (ell_mean + 1) * 5.13 * 1e-4 * (1000 / ell_mean) ** 2.34 / (2 * np.pi),
        color="k",
        label="Model",
        alpha=0.75)
    axs[1].set_yscale("log")
    axs[1].set_xscale("log")
    # axs[1].set_ylim(ell_mean[-1] * (ell_mean[-1] + 1) * 5.13 * 1e-4 * (1000 / ell_mean[-1]) ** 2.34 / (2 * np.pi),
    #     ell_mean[0] * (ell_mean[0] + 1) * 5.13 * 1e-4 * (1000 / ell_mean[0]) ** 2.34 / (2 * np.pi))
    # axs[1].set_xlim(1e2, 1e4)
    axs[1].grid()
    axs[1].set_xlabel(r"$\ell$", fontsize=14)
    axs[1].set_ylabel(r"$\ell(\ell + 1)C_{\ell}/2\pi$ $[K^2]$", fontsize=14)
    axs[1].legend()
    # Create the folder if it does not exist
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    plt.savefig(file_path, dpi=img_dpi)
    # plt.show()


def setup(config, bls, vis):
    # Determine which function to use based on the configuration
    estimator_func_choice = config.get('computation_type')
    if estimator_func_choice == 'cupy':
        bare_estimator_func = bare_estimator_func_cupy
    elif estimator_func_choice == 'noMP':
        bare_estimator_func = bare_estimator_func_v4_noMP
    elif estimator_func_choice == 'MP':
        bare_estimator_func = bare_estimator_func_v4
    else:
        print('Computation type input invalid. Can be \'MP\' for multiprocessing,',
              '\'noMP\' for no multiprocessing, and \'cupy\'.')
        
    
    binning_method = config["binning_method"]
    num_bins = config["num_bins"]
    theta_maj = config["theta_maj"]
    theta_min = config["theta_min"]
    theta_fwhm= np.mean([theta_maj, theta_min])

    bare_estimator, ell_mean, var_squared= bare_estimator_func(bls, vis, theta_fwhm, num_bins, binning_method)
    
    return bare_estimator, ell_mean, var_squared


def parse_timesteps(timesteps_config):
    if isinstance(timesteps_config, str):
        start, end = map(int, timesteps_config.split(':'))
        return list(range(start, end))
    elif isinstance(timesteps_config, list):
        return timesteps_config
    else:
        raise ValueError("Invalid format for timesteps. Use a list or a range string (e.g., '50:60').")

# %% [markdown]
# ***
# ## __All functions for the cupy option.__

# %%
def _splice_values_equal_bins_cupy(blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    """
    The provided arrays should be cupy arrays.
    """
    # Step 1: Calculate the number of elements per bin
    num_elements = len(blmag_sorted)
    elements_per_bin = num_elements // num_bins
    extra_elements = num_elements % num_bins

    # Step 2: Create an array of bin sizes
    bin_sizes = cp.full(num_bins, elements_per_bin)
    bin_sizes[:extra_elements] += 1

    # Step 3: Calculate the cumulative sum of bin sizes
    cumulative_sizes = cp.cumsum(bin_sizes)
    cumulative_sizes_np = cp.asnumpy(cumulative_sizes)  # Convert to NumPy array

    # Step 4: Initialize the bins
    blcoord_bins = cp.split(blcoord_sorted, cumulative_sizes_np[:-1])
    blmag_bins = cp.split(blmag_sorted, cumulative_sizes_np[:-1])
    vis_bins = cp.split(vis_sorted, cumulative_sizes_np[:-1])

    return blcoord_bins, blmag_bins, vis_bins

def _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    bins = cp.linspace(np.min(blmag_sorted_transformed), np.max(blmag_sorted_transformed), num_bins)
    bin_indices = np.digitize(blmag_sorted_transformed, bins) - 1
    
    # Use histogram to count the occurrences of each bin
    hist, _ = cp.histogram(bin_indices, bins=cp.arange(0, num_bins + 1))

    # Calculate the cumulative counts to determine the indices where each bin's values start and end
    cum_counts = cp.cumsum(hist)
    cumulative_sizes_np = cp.asnumpy(cum_counts)  # Convert to NumPy array

    bin_blcoords = cp.split(blcoord_sorted, cumulative_sizes_np[:-1])
    bin_vis = cp.split(vis_sorted, cumulative_sizes_np[:-1])
    bin_blmags = cp.split(blmag_sorted, cumulative_sizes_np[:-1])

    return bin_blcoords, bin_vis, bin_blmags


def compute_vals_cupy(blcoord, vis, sigma_0, V_0, bin_number):

    bin_len = len(blcoord)
    if bin_len == 0 or bin_len == 1:
        return 0, 0, 0

    # Create a meshgrid for vectorized pairwise operations
    idx_i, idx_j = np.triu_indices(bin_len, k=1)
    idx_i = cp.asarray(idx_i)
    idx_j = cp.asarray(idx_j)

    # Calculate pairwise distances
    delta= blcoord[idx_i] - blcoord[idx_j]
    distance_norm = cp.linalg.norm(delta, axis=1)
    
    combination_len_unfiltered= len(distance_norm)
    
    # Filter pairs where distance is less than or equal to sigma_0
    valid_pairs = distance_norm > sigma_0
    if not cp.any(valid_pairs):
        return 0, 0, 0

    distance_norm = distance_norm[valid_pairs]
    idx_i = idx_i[valid_pairs]
    idx_j = idx_j[valid_pairs]
    
    combination_len_filtered= len(distance_norm)
    print("Bin", bin_number, ":Theoretical combinations: ", combination_len_unfiltered,
         " - When filtered: ", combination_len_filtered)
    
    # Calculate weights
    weight = cp.exp(-(distance_norm**2) / sigma_0**2)

    # Calculate the visibility product
    visibility_product = vis[idx_i] * cp.conj(vis[idx_j])

    #Calclating the bare estimator
    be_numerator = cp.sum(weight * visibility_product)
    be_denominator = cp.sum(weight * V_0 * cp.exp(-(distance_norm**2) / (sigma_0**2)))

    #Calculating the mean of ell
    l_i = 2 * cp.pi * cp.sqrt(blcoord[idx_i, 0]**2 + blcoord[idx_i, 1]**2)
    exp_weight_distance = weight * cp.exp(-(distance_norm**2) / (sigma_0**2))

    ell_numerator = cp.sum(exp_weight_distance * l_i)
    ell_denominator = cp.sum(exp_weight_distance)

    #Computing arrays needed for the error (variance)
    Eb_square_mean_numerator = cp.sum((exp_weight_distance * 5.13 * 1e-4 * (1000 / l_i) ** 2.34) ** 2)
    Eb_mean_square_numerator = cp.sum(exp_weight_distance * 5.13 * 1e-4 * (1000 / l_i) ** 2.34)
    Eb_denominator = cp.sum(exp_weight_distance)

    bare_estimator = cp.abs(be_numerator) / be_denominator
    ell_mean = ell_numerator / ell_denominator
    var_squared = (Eb_square_mean_numerator / Eb_denominator - (Eb_mean_square_numerator / Eb_denominator) ** 2)

    # Convert results back to numpy arrays
    bare_estimator = cp.asnumpy(bare_estimator)
    ell_mean = cp.asnumpy(ell_mean)
    var_squared = cp.asnumpy(var_squared)

    return bare_estimator, ell_mean, np.abs(var_squared)


def bare_estimator_func_cupy(baselines, visibilities, theta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm

    start_time = time.time()
    # Step 0: turn arrays into cupy arrays
    baselines= cp.asarray(baselines, dtype= cp.float32)
    visibilities= cp.asarray(visibilities, dtype= cp.complex64)

    # Step 1: Calculate the baseline magnitudes
    bl_mag = cp.linalg.norm(baselines, axis=1)

    # Stack baselines, magnitudes, and visibilities into a single array for sorting
    #combined_array = cp.hstack((baselines[:,0, None], baselines[:,1, None], bl_mag[:, None], visibilities[:, None]))
    combined_array = cp.hstack((baselines[:], bl_mag[:, None], visibilities[:, None]))

    # Sort the combined array based on the magnitudes
    sorted_combined_array = combined_array[cp.argsort(combined_array[:,2])]

    # Split the sorted array back into individual components
    blcoord_sorted = sorted_combined_array[:, 0:2]
    blcoord_sorted = blcoord_sorted.astype(cp.float32)  # Change to desired dtype
    blmag_sorted = sorted_combined_array[:, 2]
    blmag_sorted = blmag_sorted.astype(cp.float32)      # Change to desired dtype
    vis_sorted = sorted_combined_array[:, -1]
    vis_sorted = vis_sorted.astype(cp.complex64)          # Change to desired dtype

    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = cp.log10(blmag_sorted)
        blcoord_bins, blmag_bins, vis_bins = _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        blcoord_bins, blmag_bins, vis_bins = _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        blcoord_bins, blmag_bins, vis_bins = _splice_values_equal_bins_cupy(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")

    end_time = time.time()
    print('Time to sort and bin values: ', end_time-start_time, 's')

    # Verify the bins
    for i, bin in enumerate(blcoord_bins):
        print(f"Bin {i+1}: {len(bin)} elements - Combinations: {int(len(bin)*(len(bin)-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", cp.sum(cp.array([len(bin) for bin in blmag_bins])))

    bare_estimators = np.empty(num_bins, dtype=np.float32)
    average_ells = np.empty(num_bins, dtype=np.float32)
    square_variances = np.empty(num_bins, dtype=np.float32)

    start_time = time.time()
    for i in range(num_bins):
        bin_number = i + 1
        BE, ell_avg, var_squared= compute_vals_cupy(blcoord_bins[i], vis_bins[i], sigma_0, V_0, bin_number) 

        bare_estimators[i] = BE
        average_ells[i] = ell_avg
        square_variances[i] = var_squared
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    return bare_estimators, average_ells, square_variances

# %% [markdown]
# ***
# ## __All functions for the multiprocessing option.__

# %%
def compute_vals(bin_values, sigma_0, V_0, bin_number):
    bin_len = len(bin_values)

    if bin_len == 0 or bin_len == 1:
        return 0, 0, 0

    be_numerator = 0
    be_denominator = 0
    ell_numerator = 0
    ell_denominator = 0
    cntr = 0
    Eb_square_mean_numerator = 0
    Eb_mean_square_numerator = 0
    Eb_denominator = 0

    pair_combs = list(itertools.combinations(range(bin_len), 2))
    for i in range(len(pair_combs)):
        distance = bin_values[pair_combs[i][0]][0] - bin_values[pair_combs[i][1]][0]
        distance_norm = np.linalg.norm(distance)

        if distance_norm <= sigma_0:
            continue

        cntr += 1
        weight = np.exp(-(distance_norm**2) / sigma_0**2)
        visibility_product = bin_values[pair_combs[i][0]][2] * np.conj(bin_values[pair_combs[i][1]][2])
        be_numerator += weight * visibility_product
        be_denominator += weight * V_0 * np.exp(-(distance_norm**2) / (sigma_0**2))

        u_i = bin_values[pair_combs[i][0]][0][0]
        v_i = bin_values[pair_combs[i][0]][0][1]
        l_i = 2 * np.pi * np.sqrt(u_i**2 + v_i**2)
        ell_numerator += weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * l_i
        ell_denominator += weight * np.exp(-(distance_norm**2) / (sigma_0**2))

        Eb_square_mean_numerator += (weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * 5.13 * 1e-4 * (1000 / l_i) ** 2.34) ** 2
        Eb_mean_square_numerator += (weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * 5.13 * 1e-4 * (1000 / l_i) ** 2.34)
        Eb_denominator += weight * np.exp(-(distance_norm**2) / (sigma_0**2))

    if distance_norm <= sigma_0:
        return 0, 0, 0
    
    print("Bin", bin_number, ":Theoretical combinations: ", len(pair_combs),
         " - When filtered: ", cntr)

    bare_estimator = np.abs(be_numerator) / be_denominator
    ell_mean = ell_numerator / ell_denominator
    var_squared = (Eb_square_mean_numerator / Eb_denominator - (Eb_mean_square_numerator / Eb_denominator) ** 2)

    return bare_estimator, ell_mean, np.abs(var_squared)


def _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    bins = np.linspace(np.min(blmag_sorted_transformed), np.max(blmag_sorted_transformed), num_bins)
    bin_indices = np.digitize(blmag_sorted_transformed, bins)

    # Initialize a dictionary to store the baseline coordinates, baseline magnitudes and visibility values
    bin_values = {i: [] for i in range(1, num_bins + 1)}
    # Group the values based on the bin indices
    for i, bin_index in enumerate(bin_indices):
        bin_values[bin_index].append((blcoord_sorted[i], blmag_sorted[i], vis_sorted[i]))

    return bin_values


def _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    # Calculate number of elements per bin
    elements_per_bin = len(blmag_sorted) // num_bins
    remainder = len(blmag_sorted) % num_bins

    bin_values = {}

    # Distribute elements into bins
    start_idx = 0
    for i in range(num_bins):
        end_idx = start_idx + elements_per_bin
        if i < remainder:
            end_idx += 1  # Distribute remainder elements
        bin_values[i + 1] = list(zip(blcoord_sorted[start_idx:end_idx], blmag_sorted[start_idx:end_idx], vis_sorted[start_idx:end_idx],))
        start_idx = end_idx
    return bin_values


def bare_estimator_func_v4(baselines, visibilities, theta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm
    
    start_time = time.time()
    #Calculating baseline magnitudes and sorting the three arrays according to them
    bl_mag = np.linalg.norm(baselines, axis=1)
    blcoord_blmag_vis = zip(baselines, bl_mag, visibilities)
    sorted_blcoord_blmag_vis = sorted(blcoord_blmag_vis, key=lambda x: x[1])
    blcoord_sorted, blmag_sorted, vis_sorted = zip(*sorted_blcoord_blmag_vis)
    
    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = np.log10(blmag_sorted)
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
        
    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        bin_values = _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")
        
    end_time = time.time()
    print('Time to sort and bin values: ', end_time - start_time, 's')
    
    #Verify the bins
    total_elements = 0 # Initialize the total length variable
    for i in range(len(bin_values)):
        bin_len = len(bin_values[i+1])
        total_elements += bin_len
        print(f"Bin {i+1}: {bin_len} elements - Combinations: {int(bin_len*(bin_len-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", total_elements)
    
    start_time = time.time()
    # create a pool of processes
    pool = mp.Pool(processes=num_bins)
    # map the function to the input data and calculate the results
    results = pool.starmap(
        compute_vals, [(bin_values[key], sigma_0, V_0, key) for key in bin_values.keys()]
    )
    pool.close()
    pool.join()
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    # Combine the results from the processes
    bare_estimator = []
    ell_mean = []
    var_squared = []
    for result in results:
        bare_estimator.append(result[0])
        ell_mean.append(result[1])
        var_squared.append(result[2])

    np_bare_estimator = np.array(bare_estimator)
    np_ell_mean = np.array(ell_mean)
    np_var_squared = np.array(var_squared)
    
    # remove zero values from the arrays
    #np_bare_estimator = np_bare_estimator[np_bare_estimator != 0]
    #np_ell_mean = np_ell_mean[np_ell_mean != 0]
    #np_var_squared = np_var_squared[np_var_squared != 0]

    return np_bare_estimator, np_ell_mean, np_var_squared

# %% [markdown]
# ***
# ## __All functions for the non-multiprocessing option.__

# %%
def bare_estimator_func_v4_noMP(baselines, visibilities, theta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm
    
    start_time = time.time()
    #Calculating baseline magnitudes and sorting the three arrays according to them
    bl_mag = np.linalg.norm(baselines, axis=1)
    blcoord_blmag_vis = zip(baselines, bl_mag, visibilities)
    sorted_blcoord_blmag_vis = sorted(blcoord_blmag_vis, key=lambda x: x[1])
    blcoord_sorted, blmag_sorted, vis_sorted = zip(*sorted_blcoord_blmag_vis)
    
    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = np.log10(blmag_sorted)
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
        
    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        bin_values = _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")
        
    end_time = time.time()
    print('Time to sort and bin values: ', end_time - start_time, 's')
    
    #Verify the bins
    total_elements = 0 # Initialize the total length variable
    for i in range(len(bin_values)):
        bin_len = len(bin_values[i+1])
        total_elements += bin_len
        print(f"Bin {i+1}: {bin_len} elements - Combinations: {int(bin_len*(bin_len-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", total_elements)
    
    start_time = time.time()
    #Running the bare_estimator for every key (bin)
    results= []
    for key in bin_values.keys():
        result= compute_vals(bin_values[key], sigma_0, V_0, key)
        results.append(result)
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    # Combine the results from the processes
    bare_estimator = []
    ell_mean = []
    var_squared = []
    for result in results:
        bare_estimator.append(result[0])
        ell_mean.append(result[1])
        var_squared.append(result[2])

    np_bare_estimator = np.array(bare_estimator)
    np_ell_mean = np.array(ell_mean)
    np_var_squared = np.array(var_squared)
    
    # remove zero values from the arrays
    #np_bare_estimator = np_bare_estimator[np_bare_estimator != 0]
    #np_ell_mean = np_ell_mean[np_ell_mean != 0]
    #np_var_squared = np_var_squared[np_var_squared != 0]

    return np_bare_estimator, np_ell_mean, np_var_squared

# %%
if __name__ == "__main__":
    config = read_config("input/config_SKA_multistep.yaml")
    
    #Setting the timestep list using the parse_timesteps function
    timesteps = parse_timesteps(config["timesteps"])
    
    num_times= config["num_times"]
    theta_maj = config["theta_maj"]
    theta_min = config["theta_min"]
    theta_fwhm = np.mean([theta_maj, theta_min])
    filter_baselines_enabled = config.get("filter_baselines_enabled", True)
    
    num_bins = config["num_bins"]
    all_bare_ests  = np.empty((len(timesteps), num_bins))
    all_ell_means = np.empty((len(timesteps), num_bins))
    all_var_squares = np.empty((len(timesteps), num_bins))

    all_bls= np.load('baselines_all_dTgf_32.npy', mmap_mode='r')
    all_vis= np.load('visibilities_all_dTgf.npy', mmap_mode='r')

    uv_range= config["uv_range"]

    timestep_len= len(all_bls) // num_times

    for count, timestep in enumerate(timesteps):
        print('*'*50)
        print('Timestep', timestep)
        bls= all_bls[timestep * timestep_len : (timestep + 1) * timestep_len]
        vis= all_vis[timestep * timestep_len : (timestep + 1) * timestep_len]
        
        # Decides whether to filter the baselines based on the uv range
        if filter_baselines_enabled:
            bls_filter, vis_filter = filter_baselines_cupy(bls, vis, uv_range, uv_range)
        else:
            bls_filter = bls
            vis_filter = vis
        
        # Filters baselines with 0 visibility
        non_zero_indices = np.where(vis_filter != 0)[0]
        bls_filter = bls_filter[non_zero_indices]
        # np.squeeze because the visibility dimension has to be (len(vis),)
        vis_filter = np.squeeze(vis_filter[non_zero_indices])

        # Initializing the setup and the bare estimator computation
        bare_estimator, ell_mean, var_squared = setup(config, bls_filter, vis_filter)
        
        # Squeeze the arrays to remove single-dimensional entries
        all_bare_ests[count] = np.squeeze(bare_estimator)
        all_ell_means[count] = np.squeeze(ell_mean)
        all_var_squares[count] = np.squeeze(var_squared)
    
    bare_estimator_avg= np.mean(all_bare_ests, axis=0)
    ell_mean_avg= np.mean(all_ell_means, axis=0)
    var_squared_avg= np.mean(all_var_squares, axis=0)

    print("Bare estimator values:", bare_estimator_avg)
    print("Ell mean values:", ell_mean_avg)
    print("Variance squared values:", var_squared_avg)
    
    # Generate filename based on filtering setting
    if filter_baselines_enabled:
        filename_plot = (
            f"PLT_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"uvRngPm{uv_range[-1]}_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
        
        filename_npz= (
            f"NPARR_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"uvRngPm{uv_range[-1]}_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
    else:
        filename_plot = (
            f"PLT_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"nofilter_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
        
        filename_npz =  (
            f"NPARR_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"nofilter_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
    
    
    # Plot the results
    full_file_path_plot = os.path.join(os.path.dirname("output/"), filename_plot)
    plot(bare_estimator_avg, ell_mean_avg, var_squared_avg, file_path=full_file_path_plot, img_dpi=config['img_dpi'])
    
    # Save the arrays as a numpy file
    full_file_path_npz = os.path.join(os.path.dirname("output/"), filename_npz)
    npz_filename = os.path.splitext(full_file_path_npz)[0] + ".npz"
    np.savez(npz_filename, bare_estimator_avg=bare_estimator_avg, ell_mean_avg=ell_mean_avg, var_squared_avg=var_squared_avg)
# Out:
# **************************************************
# Timestep 0
# Length of input arrays:  57596
# Time to sort and bin values:  0.001470327377319336 s
# Bin 1: 2880 elements - Combinations: 4145760
# Bin 2: 2880 elements - Combinations: 4145760
# Bin 3: 2880 elements - Combinations: 4145760
# Bin 4: 2880 elements - Combinations: 4145760
# Bin 5: 2880 elements - Combinations: 4145760
# Bin 6: 2880 elements - Combinations: 4145760
# Bin 7: 2880 elements - Combinations: 4145760
# Bin 8: 2880 elements - Combinations: 4145760
# Bin 9: 2880 elements - Combinations: 4145760
# Bin 10: 2880 elements - Combinations: 4145760
# Bin 11: 2880 elements - Combinations: 4145760
# Bin 12: 2880 elements - Combinations: 4145760
# Bin 13: 2880 elements - Combinations: 4145760
# Bin 14: 2880 elements - Combinations: 4145760
# Bin 15: 2880 elements - Combinations: 4145760
# Bin 16: 2880 elements - Combinations: 4145760
# Bin 17: 2879 elements - Combinations: 4142881
# Bin 18: 2879 elements - Combinations: 4142881
# Bin 19: 2879 elements - Combinations: 4142881
# Bin 20: 2879 elements - Combinations: 4142881
# Total elements after binning:  57596
# Bin 1 :Theoretical combinations:  4145760  - When filtered:  4049531
# Bin 2 :Theoretical combinations:  4145760  - When filtered:  4095786
# Bin 3 :Theoretical combinations:  4145760  - When filtered:  4102305
# Bin 4 :Theoretical combinations:  4145760  - When filtered:  4108061
# Bin 5 :Theoretical combinations:  4145760  - When filtered:  4113339
# Bin 6 :Theoretical combinations:  4145760  - When filtered:  4117733
# Bin 7 :Theoretical combinations:  4145760  - When filtered:  4122147
# Bin 8 :Theoretical combinations:  4145760  - When filtered:  4126468
# Bin 9 :Theoretical combinations:  4145760  - When filtered:  4130808
# Bin 10 :Theoretical combinations:  4145760  - When filtered:  4135646
# Bin 11 :Theoretical combinations:  4145760  - When filtered:  4139580
# Bin 12 :Theoretical combinations:  4145760  - When filtered:  4141460
# Bin 13 :Theoretical combinations:  4145760  - When filtered:  4142255
# Bin 14 :Theoretical combinations:  4145760  - When filtered:  4142382
# Bin 15 :Theoretical combinations:  4145760  - When filtered:  4142759
# Bin 16 :Theoretical combinations:  4145760  - When filtered:  4142803
# Bin 17 :Theoretical combinations:  4142881  - When filtered:  4140233
# Bin 18 :Theoretical combinations:  4142881  - When filtered:  4140250
# Bin 19 :Theoretical combinations:  4142881  - When filtered:  4140066
# Bin 20 :Theoretical combinations:  4142881  - When filtered:  4140184
# Time to run the bare estimator:  1.6230602264404297 s
# **************************************************
# Timestep 1
# Length of input arrays:  57592
# Time to sort and bin values:  0.0010707378387451172 s
# Bin 1: 2880 elements - Combinations: 4145760
# Bin 2: 2880 elements - Combinations: 4145760
# Bin 3: 2880 elements - Combinations: 4145760
# Bin 4: 2880 elements - Combinations: 4145760
# Bin 5: 2880 elements - Combinations: 4145760
# Bin 6: 2880 elements - Combinations: 4145760
# Bin 7: 2880 elements - Combinations: 4145760
# Bin 8: 2880 elements - Combinations: 4145760
# Bin 9: 2880 elements - Combinations: 4145760
# Bin 10: 2880 elements - Combinations: 4145760
# Bin 11: 2880 elements - Combinations: 4145760
# Bin 12: 2880 elements - Combinations: 4145760
# Bin 13: 2879 elements - Combinations: 4142881
# Bin 14: 2879 elements - Combinations: 4142881
# Bin 15: 2879 elements - Combinations: 4142881
# Bin 16: 2879 elements - Combinations: 4142881
# Bin 17: 2879 elements - Combinations: 4142881
# Bin 18: 2879 elements - Combinations: 4142881
# Bin 19: 2879 elements - Combinations: 4142881
# Bin 20: 2879 elements - Combinations: 4142881
# Total elements after binning:  57592
# Bin 1 :Theoretical combinations:  4145760  - When filtered:  4049554
# Bin 2 :Theoretical combinations:  4145760  - When filtered:  4095797
# Bin 3 :Theoretical combinations:  4145760  - When filtered:  4102312
# Bin 4 :Theoretical combinations:  4145760  - When filtered:  4108072
# Bin 5 :Theoretical combinations:  4145760  - When filtered:  4113337
# Bin 6 :Theoretical combinations:  4145760  - When filtered:  4117742
# Bin 7 :Theoretical combinations:  4145760  - When filtered:  4122160
# Bin 8 :Theoretical combinations:  4145760  - When filtered:  4126482
# Bin 9 :Theoretical combinations:  4145760  - When filtered:  4130803
# Bin 10 :Theoretical combinations:  4145760  - When filtered:  4135651
# Bin 11 :Theoretical combinations:  4145760  - When filtered:  4139580
# Bin 12 :Theoretical combinations:  4145760  - When filtered:  4141463
# Bin 13 :Theoretical combinations:  4142881  - When filtered:  4139379
# Bin 14 :Theoretical combinations:  4142881  - When filtered:  4139506
# Bin 15 :Theoretical combinations:  4142881  - When filtered:  4139882
# Bin 16 :Theoretical combinations:  4142881  - When filtered:  4139922
# Bin 17 :Theoretical combinations:  4142881  - When filtered:  4140235
# Bin 18 :Theoretical combinations:  4142881  - When filtered:  4140253
# Bin 19 :Theoretical combinations:  4142881  - When filtered:  4140062
# Bin 20 :Theoretical combinations:  4142881  - When filtered:  4140190
# Time to run the bare estimator:  1.6123523712158203 s
# **************************************************
# Timestep 2
# Length of input arrays:  57581
# Time to sort and bin values:  0.0011258125305175781 s
# Bin 1: 2880 elements - Combinations: 4145760
# Bin 2: 2879 elements - Combinations: 4142881
# Bin 3: 2879 elements - Combinations: 4142881
# Bin 4: 2879 elements - Combinations: 4142881
# Bin 5: 2879 elements - Combinations: 4142881
# Bin 6: 2879 elements - Combinations: 4142881
# Bin 7: 2879 elements - Combinations: 4142881
# Bin 8: 2879 elements - Combinations: 4142881
# Bin 9: 2879 elements - Combinations: 4142881
# Bin 10: 2879 elements - Combinations: 4142881
# Bin 11: 2879 elements - Combinations: 4142881
# Bin 12: 2879 elements - Combinations: 4142881
# Bin 13: 2879 elements - Combinations: 4142881
# Bin 14: 2879 elements - Combinations: 4142881
# Bin 15: 2879 elements - Combinations: 4142881
# Bin 16: 2879 elements - Combinations: 4142881
# Bin 17: 2879 elements - Combinations: 4142881
# Bin 18: 2879 elements - Combinations: 4142881
# Bin 19: 2879 elements - Combinations: 4142881
# Bin 20: 2879 elements - Combinations: 4142881
# Total elements after binning:  57581
# Bin 1 :Theoretical combinations:  4145760  - When filtered:  4049577
# Bin 2 :Theoretical combinations:  4142881  - When filtered:  4092945
# Bin 3 :Theoretical combinations:  4142881  - When filtered:  4099456
# Bin 4 :Theoretical combinations:  4142881  - When filtered:  4105211
# Bin 5 :Theoretical combinations:  4142881  - When filtered:  4110494
# Bin 6 :Theoretical combinations:  4142881  - When filtered:  4114881
# Bin 7 :Theoretical combinations:  4142881  - When filtered:  4119282
# Bin 8 :Theoretical combinations:  4142881  - When filtered:  4123622
# Bin 9 :Theoretical combinations:  4142881  - When filtered:  4127925
# Bin 10 :Theoretical combinations:  4142881  - When filtered:  4132764
# Bin 11 :Theoretical combinations:  4142881  - When filtered:  4136704
# Bin 12 :Theoretical combinations:  4142881  - When filtered:  4138586
# Bin 13 :Theoretical combinations:  4142881  - When filtered:  4139371
# Bin 14 :Theoretical combinations:  4142881  - When filtered:  4139497
# Bin 15 :Theoretical combinations:  4142881  - When filtered:  4139882
# Bin 16 :Theoretical combinations:  4142881  - When filtered:  4139920
# Bin 17 :Theoretical combinations:  4142881  - When filtered:  4140237
# Bin 18 :Theoretical combinations:  4142881  - When filtered:  4140259
# Bin 19 :Theoretical combinations:  4142881  - When filtered:  4140059
# Bin 20 :Theoretical combinations:  4142881  - When filtered:  4140193
# Time to run the bare estimator:  1.6117563247680664 s
# **************************************************
# Timestep 3
# Length of input arrays:  57575
# Time to sort and bin values:  0.0011277198791503906 s
# Bin 1: 2879 elements - Combinations: 4142881
# Bin 2: 2879 elements - Combinations: 4142881
# Bin 3: 2879 elements - Combinations: 4142881
# Bin 4: 2879 elements - Combinations: 4142881
# Bin 5: 2879 elements - Combinations: 4142881
# Bin 6: 2879 elements - Combinations: 4142881
# Bin 7: 2879 elements - Combinations: 4142881
# Bin 8: 2879 elements - Combinations: 4142881
# Bin 9: 2879 elements - Combinations: 4142881
# Bin 10: 2879 elements - Combinations: 4142881
# Bin 11: 2879 elements - Combinations: 4142881
# Bin 12: 2879 elements - Combinations: 4142881
# Bin 13: 2879 elements - Combinations: 4142881
# Bin 14: 2879 elements - Combinations: 4142881
# Bin 15: 2879 elements - Combinations: 4142881
# Bin 16: 2878 elements - Combinations: 4140003
# Bin 17: 2878 elements - Combinations: 4140003
# Bin 18: 2878 elements - Combinations: 4140003
# Bin 19: 2878 elements - Combinations: 4140003
# Bin 20: 2878 elements - Combinations: 4140003
# Total elements after binning:  57575
# Bin 1 :Theoretical combinations:  4142881  - When filtered:  4046741
# Bin 2 :Theoretical combinations:  4142881  - When filtered:  4092957
# Bin 3 :Theoretical combinations:  4142881  - When filtered:  4099469
# Bin 4 :Theoretical combinations:  4142881  - When filtered:  4105229
# Bin 5 :Theoretical combinations:  4142881  - When filtered:  4110517
# Bin 6 :Theoretical combinations:  4142881  - When filtered:  4114885
# Bin 7 :Theoretical combinations:  4142881  - When filtered:  4119283
# Bin 8 :Theoretical combinations:  4142881  - When filtered:  4123612
# Bin 9 :Theoretical combinations:  4142881  - When filtered:  4127925
# Bin 10 :Theoretical combinations:  4142881  - When filtered:  4132763
# Bin 11 :Theoretical combinations:  4142881  - When filtered:  4136699
# Bin 12 :Theoretical combinations:  4142881  - When filtered:  4138588
# Bin 13 :Theoretical combinations:  4142881  - When filtered:  4139367
# Bin 14 :Theoretical combinations:  4142881  - When filtered:  4139496
# Bin 15 :Theoretical combinations:  4142881  - When filtered:  4139881
# Bin 16 :Theoretical combinations:  4140003  - When filtered:  4137046
# Bin 17 :Theoretical combinations:  4140003  - When filtered:  4137359
# Bin 18 :Theoretical combinations:  4140003  - When filtered:  4137385
# Bin 19 :Theoretical combinations:  4140003  - When filtered:  4137184
# Bin 20 :Theoretical combinations:  4140003  - When filtered:  4137327
# Time to run the bare estimator:  1.6221044063568115 s
# **************************************************
# Timestep 4
# Length of input arrays:  57570
# Time to sort and bin values:  0.0011029243469238281 s
# Bin 1: 2879 elements - Combinations: 4142881
# Bin 2: 2879 elements - Combinations: 4142881
# Bin 3: 2879 elements - Combinations: 4142881
# Bin 4: 2879 elements - Combinations: 4142881
# Bin 5: 2879 elements - Combinations: 4142881
# Bin 6: 2879 elements - Combinations: 4142881
# Bin 7: 2879 elements - Combinations: 4142881
# Bin 8: 2879 elements - Combinations: 4142881
# Bin 9: 2879 elements - Combinations: 4142881
# Bin 10: 2879 elements - Combinations: 4142881
# Bin 11: 2878 elements - Combinations: 4140003
# Bin 12: 2878 elements - Combinations: 4140003
# Bin 13: 2878 elements - Combinations: 4140003
# Bin 14: 2878 elements - Combinations: 4140003
# Bin 15: 2878 elements - Combinations: 4140003
# Bin 16: 2878 elements - Combinations: 4140003
# Bin 17: 2878 elements - Combinations: 4140003
# Bin 18: 2878 elements - Combinations: 4140003
# Bin 19: 2878 elements - Combinations: 4140003
# Bin 20: 2878 elements - Combinations: 4140003
# Total elements after binning:  57570
# Bin 1 :Theoretical combinations:  4142881  - When filtered:  4046768
# Bin 2 :Theoretical combinations:  4142881  - When filtered:  4092960
# Bin 3 :Theoretical combinations:  4142881  - When filtered:  4099481
# Bin 4 :Theoretical combinations:  4142881  - When filtered:  4105245
# Bin 5 :Theoretical combinations:  4142881  - When filtered:  4110527
# Bin 6 :Theoretical combinations:  4142881  - When filtered:  4114895
# Bin 7 :Theoretical combinations:  4142881  - When filtered:  4119278
# Bin 8 :Theoretical combinations:  4142881  - When filtered:  4123612
# Bin 9 :Theoretical combinations:  4142881  - When filtered:  4127933
# Bin 10 :Theoretical combinations:  4142881  - When filtered:  4132764
# Bin 11 :Theoretical combinations:  4140003  - When filtered:  4133821
# Bin 12 :Theoretical combinations:  4140003  - When filtered:  4135714
# Bin 13 :Theoretical combinations:  4140003  - When filtered:  4136494
# Bin 14 :Theoretical combinations:  4140003  - When filtered:  4136623
# Bin 15 :Theoretical combinations:  4140003  - When filtered:  4137010
# Bin 16 :Theoretical combinations:  4140003  - When filtered:  4137047
# Bin 17 :Theoretical combinations:  4140003  - When filtered:  4137364
# Bin 18 :Theoretical combinations:  4140003  - When filtered:  4137381
# Bin 19 :Theoretical combinations:  4140003  - When filtered:  4137183
# Bin 20 :Theoretical combinations:  4140003  - When filtered:  4137333
# Time to run the bare estimator:  1.6125645637512207 s
# **************************************************
# Timestep 5
# Length of input arrays:  57561
# Time to sort and bin values:  0.0011143684387207031 s
# Bin 1: 2879 elements - Combinations: 4142881
# Bin 2: 2878 elements - Combinations: 4140003
# Bin 3: 2878 elements - Combinations: 4140003
# Bin 4: 2878 elements - Combinations: 4140003
# Bin 5: 2878 elements - Combinations: 4140003
# Bin 6: 2878 elements - Combinations: 4140003
# Bin 7: 2878 elements - Combinations: 4140003
# Bin 8: 2878 elements - Combinations: 4140003
# Bin 9: 2878 elements - Combinations: 4140003
# Bin 10: 2878 elements - Combinations: 4140003
# Bin 11: 2878 elements - Combinations: 4140003
# Bin 12: 2878 elements - Combinations: 4140003
# Bin 13: 2878 elements - Combinations: 4140003
# Bin 14: 2878 elements - Combinations: 4140003
# Bin 15: 2878 elements - Combinations: 4140003
# Bin 16: 2878 elements - Combinations: 4140003
# Bin 17: 2878 elements - Combinations: 4140003
# Bin 18: 2878 elements - Combinations: 4140003
# Bin 19: 2878 elements - Combinations: 4140003
# Bin 20: 2878 elements - Combinations: 4140003
# Total elements after binning:  57561
# Bin 1 :Theoretical combinations:  4142881  - When filtered:  4046791
# Bin 2 :Theoretical combinations:  4140003  - When filtered:  4090113
# Bin 3 :Theoretical combinations:  4140003  - When filtered:  4096635
# Bin 4 :Theoretical combinations:  4140003  - When filtered:  4102395
# Bin 5 :Theoretical combinations:  4140003  - When filtered:  4107683
# Bin 6 :Theoretical combinations:  4140003  - When filtered:  4112034
# Bin 7 :Theoretical combinations:  4140003  - When filtered:  4116420
# Bin 8 :Theoretical combinations:  4140003  - When filtered:  4120747
# Bin 9 :Theoretical combinations:  4140003  - When filtered:  4125069
# Bin 10 :Theoretical combinations:  4140003  - When filtered:  4129882
# Bin 11 :Theoretical combinations:  4140003  - When filtered:  4133818
# Bin 12 :Theoretical combinations:  4140003  - When filtered:  4135699
# Bin 13 :Theoretical combinations:  4140003  - When filtered:  4136487
# Bin 14 :Theoretical combinations:  4140003  - When filtered:  4136624
# Bin 15 :Theoretical combinations:  4140003  - When filtered:  4137009
# Bin 16 :Theoretical combinations:  4140003  - When filtered:  4137049
# Bin 17 :Theoretical combinations:  4140003  - When filtered:  4137366
# Bin 18 :Theoretical combinations:  4140003  - When filtered:  4137385
# Bin 19 :Theoretical combinations:  4140003  - When filtered:  4137182
# Bin 20 :Theoretical combinations:  4140003  - When filtered:  4137334
# Time to run the bare estimator:  1.613312005996704 s
# **************************************************
# Timestep 6
# Length of input arrays:  57555
# Time to sort and bin values:  0.0011415481567382812 s
# Bin 1: 2878 elements - Combinations: 4140003
# Bin 2: 2878 elements - Combinations: 4140003
# Bin 3: 2878 elements - Combinations: 4140003
# Bin 4: 2878 elements - Combinations: 4140003
# Bin 5: 2878 elements - Combinations: 4140003
# Bin 6: 2878 elements - Combinations: 4140003
# Bin 7: 2878 elements - Combinations: 4140003
# Bin 8: 2878 elements - Combinations: 4140003
# Bin 9: 2878 elements - Combinations: 4140003
# Bin 10: 2878 elements - Combinations: 4140003
# Bin 11: 2878 elements - Combinations: 4140003
# Bin 12: 2878 elements - Combinations: 4140003
# Bin 13: 2878 elements - Combinations: 4140003
# Bin 14: 2878 elements - Combinations: 4140003
# Bin 15: 2878 elements - Combinations: 4140003
# Bin 16: 2877 elements - Combinations: 4137126
# Bin 17: 2877 elements - Combinations: 4137126
# Bin 18: 2877 elements - Combinations: 4137126
# Bin 19: 2877 elements - Combinations: 4137126
# Bin 20: 2877 elements - Combinations: 4137126
# Total elements after binning:  57555
# Bin 1 :Theoretical combinations:  4140003  - When filtered:  4043962
# Bin 2 :Theoretical combinations:  4140003  - When filtered:  4090109
# Bin 3 :Theoretical combinations:  4140003  - When filtered:  4096643
# Bin 4 :Theoretical combinations:  4140003  - When filtered:  4102408
# Bin 5 :Theoretical combinations:  4140003  - When filtered:  4107678
# Bin 6 :Theoretical combinations:  4140003  - When filtered:  4112037
# Bin 7 :Theoretical combinations:  4140003  - When filtered:  4116426
# Bin 8 :Theoretical combinations:  4140003  - When filtered:  4120754
# Bin 9 :Theoretical combinations:  4140003  - When filtered:  4125069
# Bin 10 :Theoretical combinations:  4140003  - When filtered:  4129876
# Bin 11 :Theoretical combinations:  4140003  - When filtered:  4133816
# Bin 12 :Theoretical combinations:  4140003  - When filtered:  4135699
# Bin 13 :Theoretical combinations:  4140003  - When filtered:  4136489
# Bin 14 :Theoretical combinations:  4140003  - When filtered:  4136619
# Bin 15 :Theoretical combinations:  4140003  - When filtered:  4137012
# Bin 16 :Theoretical combinations:  4137126  - When filtered:  4134176
# Bin 17 :Theoretical combinations:  4137126  - When filtered:  4134489
# Bin 18 :Theoretical combinations:  4137126  - When filtered:  4134512
# Bin 19 :Theoretical combinations:  4137126  - When filtered:  4134309
# Bin 20 :Theoretical combinations:  4137126  - When filtered:  4134464
# Time to run the bare estimator:  1.6181285381317139 s
# **************************************************
# Timestep 7
# Length of input arrays:  57549
# Time to sort and bin values:  0.001148223876953125 s
# Bin 1: 2878 elements - Combinations: 4140003
# Bin 2: 2878 elements - Combinations: 4140003
# Bin 3: 2878 elements - Combinations: 4140003
# Bin 4: 2878 elements - Combinations: 4140003
# Bin 5: 2878 elements - Combinations: 4140003
# Bin 6: 2878 elements - Combinations: 4140003
# Bin 7: 2878 elements - Combinations: 4140003
# Bin 8: 2878 elements - Combinations: 4140003
# Bin 9: 2878 elements - Combinations: 4140003
# Bin 10: 2877 elements - Combinations: 4137126
# Bin 11: 2877 elements - Combinations: 4137126
# Bin 12: 2877 elements - Combinations: 4137126
# Bin 13: 2877 elements - Combinations: 4137126
# Bin 14: 2877 elements - Combinations: 4137126
# Bin 15: 2877 elements - Combinations: 4137126
# Bin 16: 2877 elements - Combinations: 4137126
# Bin 17: 2877 elements - Combinations: 4137126
# Bin 18: 2877 elements - Combinations: 4137126
# Bin 19: 2877 elements - Combinations: 4137126
# Bin 20: 2877 elements - Combinations: 4137126
# Total elements after binning:  57549
# Bin 1 :Theoretical combinations:  4140003  - When filtered:  4043981
# Bin 2 :Theoretical combinations:  4140003  - When filtered:  4090125
# Bin 3 :Theoretical combinations:  4140003  - When filtered:  4096660
# Bin 4 :Theoretical combinations:  4140003  - When filtered:  4102422
# Bin 5 :Theoretical combinations:  4140003  - When filtered:  4107680
# Bin 6 :Theoretical combinations:  4140003  - When filtered:  4112053
# Bin 7 :Theoretical combinations:  4140003  - When filtered:  4116432
# Bin 8 :Theoretical combinations:  4140003  - When filtered:  4120759
# Bin 9 :Theoretical combinations:  4140003  - When filtered:  4125074
# Bin 10 :Theoretical combinations:  4137126  - When filtered:  4127012
# Bin 11 :Theoretical combinations:  4137126  - When filtered:  4130943
# Bin 12 :Theoretical combinations:  4137126  - When filtered:  4132826
# Bin 13 :Theoretical combinations:  4137126  - When filtered:  4133613
# Bin 14 :Theoretical combinations:  4137126  - When filtered:  4133749
# Bin 15 :Theoretical combinations:  4137126  - When filtered:  4134136
# Bin 16 :Theoretical combinations:  4137126  - When filtered:  4134172
# Bin 17 :Theoretical combinations:  4137126  - When filtered:  4134488
# Bin 18 :Theoretical combinations:  4137126  - When filtered:  4134513
# Bin 19 :Theoretical combinations:  4137126  - When filtered:  4134308
# Bin 20 :Theoretical combinations:  4137126  - When filtered:  4134465
# Time to run the bare estimator:  1.6106958389282227 s
# **************************************************
# Timestep 8
# Length of input arrays:  57545
# Time to sort and bin values:  0.0010826587677001953 s
# Bin 1: 2878 elements - Combinations: 4140003
# Bin 2: 2878 elements - Combinations: 4140003
# Bin 3: 2878 elements - Combinations: 4140003
# Bin 4: 2878 elements - Combinations: 4140003
# Bin 5: 2878 elements - Combinations: 4140003
# Bin 6: 2877 elements - Combinations: 4137126
# Bin 7: 2877 elements - Combinations: 4137126
# Bin 8: 2877 elements - Combinations: 4137126
# Bin 9: 2877 elements - Combinations: 4137126
# Bin 10: 2877 elements - Combinations: 4137126
# Bin 11: 2877 elements - Combinations: 4137126
# Bin 12: 2877 elements - Combinations: 4137126
# Bin 13: 2877 elements - Combinations: 4137126
# Bin 14: 2877 elements - Combinations: 4137126
# Bin 15: 2877 elements - Combinations: 4137126
# Bin 16: 2877 elements - Combinations: 4137126
# Bin 17: 2877 elements - Combinations: 4137126
# Bin 18: 2877 elements - Combinations: 4137126
# Bin 19: 2877 elements - Combinations: 4137126
# Bin 20: 2877 elements - Combinations: 4137126
# Total elements after binning:  57545
# Bin 1 :Theoretical combinations:  4140003  - When filtered:  4044016
# Bin 2 :Theoretical combinations:  4140003  - When filtered:  4090138
# Bin 3 :Theoretical combinations:  4140003  - When filtered:  4096663
# Bin 4 :Theoretical combinations:  4140003  - When filtered:  4102431
# Bin 5 :Theoretical combinations:  4140003  - When filtered:  4107679
# Bin 6 :Theoretical combinations:  4137126  - When filtered:  4109200
# Bin 7 :Theoretical combinations:  4137126  - When filtered:  4113572
# Bin 8 :Theoretical combinations:  4137126  - When filtered:  4117902
# Bin 9 :Theoretical combinations:  4137126  - When filtered:  4122216
# Bin 10 :Theoretical combinations:  4137126  - When filtered:  4127008
# Bin 11 :Theoretical combinations:  4137126  - When filtered:  4130938
# Bin 12 :Theoretical combinations:  4137126  - When filtered:  4132821
# Bin 13 :Theoretical combinations:  4137126  - When filtered:  4133617
# Bin 14 :Theoretical combinations:  4137126  - When filtered:  4133748
# Bin 15 :Theoretical combinations:  4137126  - When filtered:  4134138
# Bin 16 :Theoretical combinations:  4137126  - When filtered:  4134176
# Bin 17 :Theoretical combinations:  4137126  - When filtered:  4134489
# Bin 18 :Theoretical combinations:  4137126  - When filtered:  4134512
# Bin 19 :Theoretical combinations:  4137126  - When filtered:  4134306
# Bin 20 :Theoretical combinations:  4137126  - When filtered:  4134474
# Time to run the bare estimator:  1.6128320693969727 s
# **************************************************
# Timestep 9
# Length of input arrays:  57541
# Time to sort and bin values:  0.0011172294616699219 s
# Bin 1: 2878 elements - Combinations: 4140003
# Bin 2: 2877 elements - Combinations: 4137126
# Bin 3: 2877 elements - Combinations: 4137126
# Bin 4: 2877 elements - Combinations: 4137126
# Bin 5: 2877 elements - Combinations: 4137126
# Bin 6: 2877 elements - Combinations: 4137126
# Bin 7: 2877 elements - Combinations: 4137126
# Bin 8: 2877 elements - Combinations: 4137126
# Bin 9: 2877 elements - Combinations: 4137126
# Bin 10: 2877 elements - Combinations: 4137126
# Bin 11: 2877 elements - Combinations: 4137126
# Bin 12: 2877 elements - Combinations: 4137126
# Bin 13: 2877 elements - Combinations: 4137126
# Bin 14: 2877 elements - Combinations: 4137126
# Bin 15: 2877 elements - Combinations: 4137126
# Bin 16: 2877 elements - Combinations: 4137126
# Bin 17: 2877 elements - Combinations: 4137126
# Bin 18: 2877 elements - Combinations: 4137126
# Bin 19: 2877 elements - Combinations: 4137126
# Bin 20: 2877 elements - Combinations: 4137126
# Total elements after binning:  57541
# Bin 1 :Theoretical combinations:  4140003  - When filtered:  4044037
# Bin 2 :Theoretical combinations:  4137126  - When filtered:  4087293
# Bin 3 :Theoretical combinations:  4137126  - When filtered:  4093807
# Bin 4 :Theoretical combinations:  4137126  - When filtered:  4099574
# Bin 5 :Theoretical combinations:  4137126  - When filtered:  4104827
# Bin 6 :Theoretical combinations:  4137126  - When filtered:  4109204
# Bin 7 :Theoretical combinations:  4137126  - When filtered:  4113575
# Bin 8 :Theoretical combinations:  4137126  - When filtered:  4117903
# Bin 9 :Theoretical combinations:  4137126  - When filtered:  4122220
# Bin 10 :Theoretical combinations:  4137126  - When filtered:  4127020
# Bin 11 :Theoretical combinations:  4137126  - When filtered:  4130938
# Bin 12 :Theoretical combinations:  4137126  - When filtered:  4132823
# Bin 13 :Theoretical combinations:  4137126  - When filtered:  4133618
# Bin 14 :Theoretical combinations:  4137126  - When filtered:  4133753
# Bin 15 :Theoretical combinations:  4137126  - When filtered:  4134130
# Bin 16 :Theoretical combinations:  4137126  - When filtered:  4134176
# Bin 17 :Theoretical combinations:  4137126  - When filtered:  4134488
# Bin 18 :Theoretical combinations:  4137126  - When filtered:  4134515
# Bin 19 :Theoretical combinations:  4137126  - When filtered:  4134308
# Bin 20 :Theoretical combinations:  4137126  - When filtered:  4134474
# Time to run the bare estimator:  1.6167359352111816 s
# Bare estimator values: [2.50859227e+04 1.83968931e+03 6.43242480e+02 2.62307236e+02
#  1.76726421e+02 1.63295503e+02 5.70789101e+01 3.22677774e+01
#  2.05867481e+01 1.13079737e+01 4.82074261e+00 1.79860916e+00
#  7.19694513e-01 8.65348920e-02 5.36855436e-03 4.80328249e-04
#  8.12393140e-05 7.88404375e-06 2.04108839e-07 6.46167790e-11]
# Ell mean values: [  460.63566895  1102.41157227  1548.26170654  1932.86279297
#   2293.20158691  2650.22978516  3019.65817871  3411.40085449
#   3859.02531738  4412.12167969  5156.45048828  6259.26196289
#   7500.63613281  9023.03232422 10549.00429688 12026.56904297
#  13523.26533203 15520.07880859 17669.92207031 20788.52226563]
# Variance squared values: [2.37181363e-05 1.70037180e-07 3.25464729e-08 1.13720856e-08
#  5.08535107e-09 2.57832540e-09 1.39857095e-09 7.89737364e-10
#  4.44043860e-10 2.37899597e-10 1.15520501e-10 4.67799841e-11
#  2.00671821e-11 8.39106033e-12 4.03524458e-12 2.17712092e-12
#  1.25769380e-12 6.61099241e-13 3.59914247e-13 1.70082252e-13]

# %%
#plt.plot(bare_estimator_avg, ell_mean_avg, var_squared_avg)

fig, axs= plt.subplots(1, 1, figsize=(7,5))
axs.scatter(ell_mean_avg, bare_estimator_avg / 1e6, color='orange')
axs.plot(ell_mean_avg, 5.13 * 1e-4 * (1000 / ell_mean_avg) ** 2.34)
axs.set_yscale('log')

# %%
print(npz_filename)
# Out:
# output/NPARR_SKA_BE_0to2steps_nofilter_bins20_equal_length.npz

# %%
# Load the .npz file
#output_folder = "output/"
#filename = output_folder + npz_filename
#data = np.load('output/' + filename)
data = np.load(npz_filename)

# Access the arrays
bare_estimator_avg = data['bare_estimator_avg']
ell_mean_avg = data['ell_mean_avg']
var_squared_avg = data['var_squared_avg']

# Print the arrays
print("Bare estimator values:", bare_estimator_avg)
print("Ell mean values:", ell_mean_avg)
print("Variance squared values:", var_squared_avg)

# Close the .npz file
data.close()
# Out:
# Bare estimator values: [2.02768503e+04 7.85046041e+02 4.09458242e+02 1.50792124e+02
#  8.81830057e+00 3.74554749e+01 1.03813674e+01 4.01054923e+00
#  1.17624482e+00 1.81529691e-01 3.62512011e-03 2.31163353e-04
#  5.46401907e-06 2.00237225e-08 5.87890903e-10 2.20983054e-17
#  4.20850772e-22 6.97355740e-37 0.00000000e+00 0.00000000e+00]
# Ell mean values: [  555.63287354  1377.57063802  1936.7130127   2443.62695312
#   2956.82356771  3512.10489909  4202.05078125  5206.65983073
#   6838.83626302  8888.67936198 11023.71744792 13086.02539062
#  15848.25683594 18978.46289062 22516.94010417 27559.5
#  31615.04361979 37649.39192708 44252.15755208 50459.9453125 ]
# Variance squared values: [1.54158151e-05 6.00093036e-08 1.14719884e-08 3.81351128e-09
#  1.55673837e-09 6.94908464e-10 3.01620035e-10 1.12334133e-10
#  3.14449358e-11 9.15730744e-12 3.31562974e-12 1.47825737e-12
#  6.05566920e-13 2.60414529e-13 1.16375320e-13 4.52762206e-14
#  2.40551919e-14 1.04113168e-14 4.98666366e-15 2.64416645e-15]
