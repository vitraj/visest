# %%
import os
import yaml
import multiprocessing as mp
import time
import tools21cm as t2c
from tqdm import tqdm
import astropy.units as u
import astropy.constants as cst
import cupy as cp
import numpy as np
import itertools

import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"


def filter_baselines(baselines, visibilities, u_freq, v_freq):
    """Filters baselines and corresponding visibilities based on the range of
    frequencies. This is so that the baselines outside the frequency range of
    the fft image are removed.

    Parameters:
    baselines (list): List of baseline coordinates.
    visibilities (list): List of corresponding visibilities.
    u_freq (list): List of u frequencies.
    v_freq (list): List of v frequencies.

    Returns:
    filtered_baselines (ndarray): Numpy array of filtered baseline coordinates.
    filtered_visibilities (ndarray): Numpy array of filtered visibilities.
    """
    filtered_baselines = []
    filtered_visibilities = []

    for baseline, visibility in zip(baselines, visibilities):
        x, y = baseline
        # Check if baseline coordinates are within the range of frequencies
        if (np.min(u_freq) <= x <= np.max(u_freq)) and (
            np.min(v_freq) <= y <= np.max(v_freq)
        ):
            filtered_baselines.append(baseline)
            filtered_visibilities.append(visibility)
    return np.array(filtered_baselines), np.array(filtered_visibilities)


def read_config(input_path):
    with open(input_path) as stream:
        try:
            config = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    return config


def plot(bare_estimator, ell_mean, var_squared, file_path, img_dpi):
    # Plot the results
    fig, axs = plt.subplots(1, 2, figsize=(17, 5))

    axs[0].errorbar(ell_mean, bare_estimator, np.sqrt(var_squared),
        color="#1f77b4",
        label="Gaussian primary beam",
        elinewidth=0.75,
        capsize=4,
        fmt="o",
        markersize=3)
    axs[0].plot(ell_mean, 5.13 * 1e-4 * (1000 / ell_mean) ** 2.34,
        color="k",
        label="Model",
        alpha=0.75)
    axs[0].set_yscale("log")
    #axs[0].set_ylim(5.13 * 1e-4 * (1000 / ell_mean[-1]) ** 2.34, 5.13 * 1e-4 * (1000 / ell_mean[0]) ** 2.34)
    axs[0].grid()
    axs[0].set_xlabel(r"$\ell$", fontsize=14)
    axs[0].set_ylabel(r"$C_{\ell}$ $[K^2]$", fontsize=14)
    axs[0].legend()

    axs[1].errorbar(ell_mean, ell_mean * (ell_mean + 1) * bare_estimator / (2 * np.pi), ell_mean * (ell_mean + 1) * np.sqrt(var_squared) / (2 * np.pi),
        color="#1f77b4",
        label="Gaussian primary beam",
        elinewidth=0.75,
        capsize=4,
        fmt="o",
        markersize=3)
    axs[1].plot(ell_mean, ell_mean * (ell_mean + 1) * 5.13 * 1e-4 * (1000 / ell_mean) ** 2.34 / (2 * np.pi),
        color="k",
        label="Model",
        alpha=0.75)
    axs[1].set_yscale("log")
    axs[1].set_xscale("log")
    # axs[1].set_ylim(ell_mean[-1] * (ell_mean[-1] + 1) * 5.13 * 1e-4 * (1000 / ell_mean[-1]) ** 2.34 / (2 * np.pi),
    #     ell_mean[0] * (ell_mean[0] + 1) * 5.13 * 1e-4 * (1000 / ell_mean[0]) ** 2.34 / (2 * np.pi))
    # axs[1].set_xlim(1e2, 1e4)
    axs[1].grid()
    axs[1].set_xlabel(r"$\ell$", fontsize=14)
    axs[1].set_ylabel(r"$\ell(\ell + 1)C_{\ell}/2\pi$ $[K^2]$", fontsize=14)
    axs[1].legend()
    # Create the folder if it does not exist
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    plt.savefig(file_path, dpi=img_dpi)
    # plt.show()


def setup(config, bls, vis):
    # Determine which function to use based on the configuration
    estimator_func_choice = config.get('computation_type')
    if estimator_func_choice == 'cupy':
        bare_estimator_func = bare_estimator_func_cupy
    elif estimator_func_choice == 'noMP':
        bare_estimator_func = bare_estimator_func_v4_noMP
    elif estimator_func_choice == 'MP':
        bare_estimator_func = bare_estimator_func_v4
    else:
        print('Computation type input invalid. Can be \'MP\' for multiprocessing,',
              '\'noMP\' for no multiprocessing, and \'cupy\'.')
        
    
    binning_method = config["binning_method"]
    num_bins = config["num_bins"]
    theta_maj = config["theta_maj"]
    theta_min = config["theta_min"]
    theta_fwhm= np.mean([theta_maj, theta_min])

    bare_estimator, ell_mean, var_squared= bare_estimator_func(bls, vis, theta_fwhm, num_bins, binning_method)
    
    return bare_estimator, ell_mean, var_squared


def parse_timesteps(timesteps_config):
    if isinstance(timesteps_config, str):
        start, end = map(int, timesteps_config.split(':'))
        return list(range(start, end))
    elif isinstance(timesteps_config, list):
        return timesteps_config
    else:
        raise ValueError("Invalid format for timesteps. Use a list or a range string (e.g., '50:60').")

# %% [markdown]
# ***
# ## __All functions for the cupy option.__

# %%
def _splice_values_equal_bins_cupy(blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    """
    The provided arrays should be cupy arrays.
    """
    # Step 1: Calculate the number of elements per bin
    num_elements = len(blmag_sorted)
    elements_per_bin = num_elements // num_bins
    extra_elements = num_elements % num_bins

    # Step 2: Create an array of bin sizes
    bin_sizes = cp.full(num_bins, elements_per_bin)
    bin_sizes[:extra_elements] += 1

    # Step 3: Calculate the cumulative sum of bin sizes
    cumulative_sizes = cp.cumsum(bin_sizes)
    cumulative_sizes_np = cp.asnumpy(cumulative_sizes)  # Convert to NumPy array

    # Step 4: Initialize the bins
    blcoord_bins = cp.split(blcoord_sorted, cumulative_sizes_np[:-1])
    blmag_bins = cp.split(blmag_sorted, cumulative_sizes_np[:-1])
    vis_bins = cp.split(vis_sorted, cumulative_sizes_np[:-1])

    return blcoord_bins, blmag_bins, vis_bins

def _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    bins = cp.linspace(np.min(blmag_sorted_transformed), np.max(blmag_sorted_transformed), num_bins)
    bin_indices = np.digitize(blmag_sorted_transformed, bins) - 1
    
    # Use histogram to count the occurrences of each bin
    hist, _ = cp.histogram(bin_indices, bins=cp.arange(0, num_bins + 1))

    # Calculate the cumulative counts to determine the indices where each bin's values start and end
    cum_counts = cp.cumsum(hist)
    cumulative_sizes_np = cp.asnumpy(cum_counts)  # Convert to NumPy array

    bin_blcoords = cp.split(blcoord_sorted, cumulative_sizes_np[:-1])
    bin_vis = cp.split(vis_sorted, cumulative_sizes_np[:-1])
    bin_blmags = cp.split(blmag_sorted, cumulative_sizes_np[:-1])

    return bin_blcoords, bin_vis, bin_blmags


def compute_vals_cupy(blcoord, vis, sigma_0, V_0, bin_number):

    bin_len = len(blcoord)
    if bin_len == 0 or bin_len == 1:
        return 0, 0, 0

    # Create a meshgrid for vectorized pairwise operations
    idx_i, idx_j = np.triu_indices(bin_len, k=1)
    idx_i = cp.asarray(idx_i)
    idx_j = cp.asarray(idx_j)

    # Calculate pairwise distances
    delta= blcoord[idx_i] - blcoord[idx_j]
    distance_norm = cp.linalg.norm(delta, axis=1)
    
    combination_len_unfiltered= len(distance_norm)
    
    # Filter pairs where distance is less than or equal to sigma_0
    valid_pairs = distance_norm > sigma_0
    if not cp.any(valid_pairs):
        return 0, 0, 0

    distance_norm = distance_norm[valid_pairs]
    idx_i = idx_i[valid_pairs]
    idx_j = idx_j[valid_pairs]
    
    combination_len_filtered= len(distance_norm)
    print("Bin", bin_number, ":Theoretical combinations: ", combination_len_unfiltered,
         " - When filtered: ", combination_len_filtered)
    
    # Calculate weights
    weight = cp.exp(-(distance_norm**2) / sigma_0**2)

    # Calculate the visibility product
    visibility_product = vis[idx_i] * cp.conj(vis[idx_j])

    #Calclating the bare estimator
    be_numerator = cp.sum(weight * visibility_product)
    be_denominator = cp.sum(weight * V_0 * cp.exp(-(distance_norm**2) / (sigma_0**2)))

    #Calculating the mean of ell
    l_i = 2 * cp.pi * cp.sqrt(blcoord[idx_i, 0]**2 + blcoord[idx_i, 1]**2)
    exp_weight_distance = weight * cp.exp(-(distance_norm**2) / (sigma_0**2))

    ell_numerator = cp.sum(exp_weight_distance * l_i)
    ell_denominator = cp.sum(exp_weight_distance)

    #Computing arrays needed for the error (variance)
    Eb_square_mean_numerator = cp.sum((exp_weight_distance * 5.13 * 1e-4 * (1000 / l_i) ** 2.34) ** 2)
    Eb_mean_square_numerator = cp.sum(exp_weight_distance * 5.13 * 1e-4 * (1000 / l_i) ** 2.34)
    Eb_denominator = cp.sum(exp_weight_distance)

    bare_estimator = cp.abs(be_numerator) / be_denominator
    ell_mean = ell_numerator / ell_denominator
    var_squared = (Eb_square_mean_numerator / Eb_denominator - (Eb_mean_square_numerator / Eb_denominator) ** 2)

    # Convert results back to numpy arrays
    bare_estimator = cp.asnumpy(bare_estimator)
    ell_mean = cp.asnumpy(ell_mean)
    var_squared = cp.asnumpy(var_squared)

    return bare_estimator, ell_mean, np.abs(var_squared)


def bare_estimator_func_cupy(baselines, visibilities, tehta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm

    start_time = time.time()
    # Step 0: turn arrays into cupy arrays
    baselines= cp.asarray(baselines, dtype= cp.float32)
    visibilities= cp.asarray(visibilities, dtype= cp.complex64)

    # Step 1: Calculate the baseline magnitudes
    bl_mag = cp.linalg.norm(baselines, axis=1)

    # Stack baselines, magnitudes, and visibilities into a single array for sorting
    #combined_array = cp.hstack((baselines[:,0, None], baselines[:,1, None], bl_mag[:, None], visibilities[:, None]))
    combined_array = cp.hstack((baselines[:], bl_mag[:, None], visibilities[:, None]))

    # Sort the combined array based on the magnitudes
    sorted_combined_array = combined_array[cp.argsort(combined_array[:,2])]

    # Split the sorted array back into individual components
    blcoord_sorted = sorted_combined_array[:, 0:2]
    blcoord_sorted = blcoord_sorted.astype(cp.float32)  # Change to desired dtype
    blmag_sorted = sorted_combined_array[:, 2]
    blmag_sorted = blmag_sorted.astype(cp.float32)      # Change to desired dtype
    vis_sorted = sorted_combined_array[:, -1]
    vis_sorted = vis_sorted.astype(cp.complex64)          # Change to desired dtype

    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = cp.log10(blmag_sorted)
        blcoord_bins, blmag_bins, vis_bins = _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        blcoord_bins, blmag_bins, vis_bins = _splice_values_function_fit_cupy(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        blcoord_bins, blmag_bins, vis_bins = _splice_values_equal_bins_cupy(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")

    end_time = time.time()
    print('Time to sort and bin values: ', end_time-start_time, 's')

    # Verify the bins
    for i, bin in enumerate(blcoord_bins):
        print(f"Bin {i+1}: {len(bin)} elements - Combinations: {int(len(bin)*(len(bin)-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", cp.sum(cp.array([len(bin) for bin in blmag_bins])))

    bare_estimators = np.empty(num_bins, dtype=np.float32)
    average_ells = np.empty(num_bins, dtype=np.float32)
    square_variances = np.empty(num_bins, dtype=np.float32)

    start_time = time.time()
    for i in range(num_bins):
        bin_number = i + 1
        BE, ell_avg, var_squared= compute_vals_cupy(blcoord_bins[i], vis_bins[i], sigma_0, V_0, bin_number) 

        bare_estimators[i] = BE
        average_ells[i] = ell_avg
        square_variances[i] = var_squared
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    return bare_estimators, average_ells, square_variances

# %% [markdown]
# ***
# ## __All functions for the multiprocessing option.__

# %%
def compute_vals(bin_values, sigma_0, V_0, bin_number):
    bin_len = len(bin_values)

    if bin_len == 0 or bin_len == 1:
        return 0, 0, 0

    be_numerator = 0
    be_denominator = 0
    ell_numerator = 0
    ell_denominator = 0
    cntr = 0
    Eb_square_mean_numerator = 0
    Eb_mean_square_numerator = 0
    Eb_denominator = 0

    pair_combs = list(itertools.combinations(range(bin_len), 2))
    for i in range(len(pair_combs)):
        distance = bin_values[pair_combs[i][0]][0] - bin_values[pair_combs[i][1]][0]
        distance_norm = np.linalg.norm(distance)

        if distance_norm <= sigma_0:
            continue

        cntr += 1
        weight = np.exp(-(distance_norm**2) / sigma_0**2)
        visibility_product = bin_values[pair_combs[i][0]][2] * np.conj(bin_values[pair_combs[i][1]][2])
        be_numerator += weight * visibility_product
        be_denominator += weight * V_0 * np.exp(-(distance_norm**2) / (sigma_0**2))

        u_i = bin_values[pair_combs[i][0]][0][0]
        v_i = bin_values[pair_combs[i][0]][0][1]
        l_i = 2 * np.pi * np.sqrt(u_i**2 + v_i**2)
        ell_numerator += weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * l_i
        ell_denominator += weight * np.exp(-(distance_norm**2) / (sigma_0**2))

        Eb_square_mean_numerator += (weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * 5.13 * 1e-4 * (1000 / l_i) ** 2.34) ** 2
        Eb_mean_square_numerator += (weight * np.exp(-(distance_norm**2) / (sigma_0**2)) * 5.13 * 1e-4 * (1000 / l_i) ** 2.34)
        Eb_denominator += weight * np.exp(-(distance_norm**2) / (sigma_0**2))

    if distance_norm <= sigma_0:
        return 0, 0, 0
    
    print("Bin", bin_number, ":Theoretical combinations: ", len(pair_combs),
         " - When filtered: ", cntr)

    bare_estimator = np.abs(be_numerator) / be_denominator
    ell_mean = ell_numerator / ell_denominator
    var_squared = (Eb_square_mean_numerator / Eb_denominator - (Eb_mean_square_numerator / Eb_denominator) ** 2)

    return bare_estimator, ell_mean, np.abs(var_squared)


def _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    bins = np.linspace(np.min(blmag_sorted_transformed), np.max(blmag_sorted_transformed), num_bins)
    bin_indices = np.digitize(blmag_sorted_transformed, bins)

    # Initialize a dictionary to store the baseline coordinates, baseline magnitudes and visibility values
    bin_values = {i: [] for i in range(1, num_bins + 1)}
    # Group the values based on the bin indices
    for i, bin_index in enumerate(bin_indices):
        bin_values[bin_index].append((blcoord_sorted[i], blmag_sorted[i], vis_sorted[i]))

    return bin_values


def _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins):
    # Calculate number of elements per bin
    elements_per_bin = len(blmag_sorted) // num_bins
    remainder = len(blmag_sorted) % num_bins

    bin_values = {}

    # Distribute elements into bins
    start_idx = 0
    for i in range(num_bins):
        end_idx = start_idx + elements_per_bin
        if i < remainder:
            end_idx += 1  # Distribute remainder elements
        bin_values[i + 1] = list(zip(blcoord_sorted[start_idx:end_idx], blmag_sorted[start_idx:end_idx], vis_sorted[start_idx:end_idx],))
        start_idx = end_idx
    return bin_values


def bare_estimator_func_v4(baselines, visibilities, theta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm
    
    start_time = time.time()
    #Calculating baseline magnitudes and sorting the three arrays according to them
    bl_mag = np.linalg.norm(baselines, axis=1)
    blcoord_blmag_vis = zip(baselines, bl_mag, visibilities)
    sorted_blcoord_blmag_vis = sorted(blcoord_blmag_vis, key=lambda x: x[1])
    blcoord_sorted, blmag_sorted, vis_sorted = zip(*sorted_blcoord_blmag_vis)
    
    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = np.log10(blmag_sorted)
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
        
    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        bin_values = _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")
        
    end_time = time.time()
    print('Time to sort and bin values: ', end_time - start_time, 's')
    
    #Verify the bins
    total_elements = 0 # Initialize the total length variable
    for i in range(len(bin_values)):
        bin_len = len(bin_values[i+1])
        total_elements += bin_len
        print(f"Bin {i+1}: {bin_len} elements - Combinations: {int(bin_len*(bin_len-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", total_elements)
    
    start_time = time.time()
    # create a pool of processes
    pool = mp.Pool(processes=num_bins)
    # map the function to the input data and calculate the results
    results = pool.starmap(
        compute_vals, [(bin_values[key], sigma_0, V_0, key) for key in bin_values.keys()]
    )
    pool.close()
    pool.join()
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    # Combine the results from the processes
    bare_estimator = []
    ell_mean = []
    var_squared = []
    for result in results:
        bare_estimator.append(result[0])
        ell_mean.append(result[1])
        var_squared.append(result[2])

    np_bare_estimator = np.array(bare_estimator)
    np_ell_mean = np.array(ell_mean)
    np_var_squared = np.array(var_squared)
    
    # remove zero values from the arrays
    #np_bare_estimator = np_bare_estimator[np_bare_estimator != 0]
    #np_ell_mean = np_ell_mean[np_ell_mean != 0]
    #np_var_squared = np_var_squared[np_var_squared != 0]

    return np_bare_estimator, np_ell_mean, np_var_squared

# %% [markdown]
# ***
# ## __All functions for the non-multiprocessing option.__

# %%
def bare_estimator_func_v4_noMP(baselines, visibilities, theta_fwhm, num_bins, bin_type):
    theta_0 = 0.6 * theta_fwhm
    V_0 = np.pi * theta_0**2 / 2
    sigma_0 = 0.76 / theta_fwhm
    
    start_time = time.time()
    #Calculating baseline magnitudes and sorting the three arrays according to them
    bl_mag = np.linalg.norm(baselines, axis=1)
    blcoord_blmag_vis = zip(baselines, bl_mag, visibilities)
    sorted_blcoord_blmag_vis = sorted(blcoord_blmag_vis, key=lambda x: x[1])
    blcoord_sorted, blmag_sorted, vis_sorted = zip(*sorted_blcoord_blmag_vis)
    
    print("Length of input arrays: ", len(blmag_sorted))

    if bin_type == "log":
        blmag_sorted_transformed = np.log10(blmag_sorted)
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
        
    elif bin_type == "linear":
        blmag_sorted_transformed = blmag_sorted
        bin_values = _splice_values_function_fit(blmag_sorted_transformed, blcoord_sorted, blmag_sorted, vis_sorted, num_bins)

    elif bin_type == "equal_length":
        bin_values = _splice_values_equal_bins(blcoord_sorted, blmag_sorted, vis_sorted, num_bins)
    else:
        raise ValueError("Unsupported bin_type")
        
    end_time = time.time()
    print('Time to sort and bin values: ', end_time - start_time, 's')
    
    #Verify the bins
    total_elements = 0 # Initialize the total length variable
    for i in range(len(bin_values)):
        bin_len = len(bin_values[i+1])
        total_elements += bin_len
        print(f"Bin {i+1}: {bin_len} elements - Combinations: {int(bin_len*(bin_len-1) / 2)}")
    # Print to verify the results
    print("Total elements after binning: ", total_elements)
    
    start_time = time.time()
    #Running the bare_estimator for every key (bin)
    results= []
    for key in bin_values.keys():
        result= compute_vals(bin_values[key], sigma_0, V_0, key)
        results.append(result)
    end_time = time.time()
    print('Time to run the bare estimator: ', end_time-start_time, 's')
    
    # Combine the results from the processes
    bare_estimator = []
    ell_mean = []
    var_squared = []
    for result in results:
        bare_estimator.append(result[0])
        ell_mean.append(result[1])
        var_squared.append(result[2])

    np_bare_estimator = np.array(bare_estimator)
    np_ell_mean = np.array(ell_mean)
    np_var_squared = np.array(var_squared)
    
    # remove zero values from the arrays
    #np_bare_estimator = np_bare_estimator[np_bare_estimator != 0]
    #np_ell_mean = np_ell_mean[np_ell_mean != 0]
    #np_var_squared = np_var_squared[np_var_squared != 0]

    return np_bare_estimator, np_ell_mean, np_var_squared

# %%
if __name__ == "__main__":
    config = read_config("input/config_SKA_multistep.yaml")
    
    #Setting the timestep list using the parse_timesteps function
    timesteps = parse_timesteps(config["timesteps"])
    
    num_times= config["num_times"]
    theta_maj = config["theta_maj"]
    theta_min = config["theta_min"]
    theta_fwhm = np.mean([theta_maj, theta_min])
    filter_baselines_enabled = config.get("filter_baselines_enabled", True)
    
    num_bins = config["num_bins"]
    all_bare_ests  = np.empty((len(timesteps), num_bins))
    all_ell_means = np.empty((len(timesteps), num_bins))
    all_var_squares = np.empty((len(timesteps), num_bins))

    all_bls= np.load('baselines_all_dTgf_32.npy', mmap_mode='r')
    all_vis= np.load('visibilities_all_dTgf.npy', mmap_mode='r')

    uv_range= config["uv_range"]

    timestep_len= len(all_bls) // num_times

    for count, timestep in enumerate(timesteps):
        print('*'*50)
        print('Timestep', timestep)
        bls= all_bls[timestep * timestep_len : (timestep + 1) * timestep_len]
        vis= all_vis[timestep * timestep_len : (timestep + 1) * timestep_len]
        
        # Decides whether to filter the baselines based on the uv range
        if filter_baselines_enabled:
            bls_filter, vis_filter = filter_baselines(bls, vis, uv_range, uv_range)
        else:
            bls_filter = bls
            vis_filter = vis
        
        # Filters baselines with 0 visibility
        non_zero_indices = np.where(vis_filter != 0)[0]
        bls_filter = bls_filter[non_zero_indices]
        # np.squeeze because the visibility dimension has to be (len(vis),)
        vis_filter = np.squeeze(vis_filter[non_zero_indices])

        # Initializing the setup and the bare estimator computation
        bare_estimator, ell_mean, var_squared = setup(config, bls_filter, vis_filter)
        
        # Squeeze the arrays to remove single-dimensional entries
        all_bare_ests[count] = np.squeeze(bare_estimator)
        all_ell_means[count] = np.squeeze(ell_mean)
        all_var_squares[count] = np.squeeze(var_squared)
    
    bare_estimator_avg= np.mean(all_bare_ests, axis=0)
    ell_mean_avg= np.mean(all_ell_means, axis=0)
    var_squared_avg= np.mean(all_var_squares, axis=0)

    print("Bare estimator values:", bare_estimator_avg)
    print("Ell mean values:", ell_mean_avg)
    print("Variance squared values:", var_squared_avg)
    
    # Generate filename based on filtering setting
    if filter_baselines_enabled:
        filename_plot = (
            f"PLT_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"uvRngPm{uv_range[-1]}_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
        
        filename_npz= (
            f"NPARR_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"uvRngPm{uv_range[-1]}_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
    else:
        filename_plot = (
            f"PLT_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"nofilter_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
        
        filename_npz =  (
            f"NPARR_SKA_BE_{timesteps[0]}to{timesteps[-1]}steps_"
            f"nofilter_"
            f"bins{config['num_bins']}_"
            f"{config['binning_method']}.png")
    
    
    # Plot the results
    full_file_path_plot = os.path.join(os.path.dirname("output/"), filename_plot)
    plot(bare_estimator, ell_mean, var_squared, file_path=full_file_path_plot, img_dpi=config['img_dpi'])
    
    # Save the arrays as a numpy file
    full_file_path_npz = os.path.join(os.path.dirname("output/"), filename_npz)
    npz_filename = os.path.splitext(full_file_path_npz)[0] + ".npz"
    np.savez(npz_filename, bare_estimator_avg=bare_estimator_avg, ell_mean_avg=ell_mean_avg, var_squared_avg=var_squared_avg)
# Out:
# **************************************************
# Timestep 0
# Length of input arrays:  81226
# Time to sort and bin values:  0.001783132553100586 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4062 elements - Combinations: 8247891
# Bin 4: 4062 elements - Combinations: 8247891
# Bin 5: 4062 elements - Combinations: 8247891
# Bin 6: 4062 elements - Combinations: 8247891
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81226
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128397
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180873
# Bin 3 :Theoretical combinations:  8247891  - When filtered:  8192610
# Bin 4 :Theoretical combinations:  8247891  - When filtered:  8202429
# Bin 5 :Theoretical combinations:  8247891  - When filtered:  8211836
# Bin 6 :Theoretical combinations:  8247891  - When filtered:  8221107
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226984
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235288
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238119
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239117
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239532
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239979
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239978
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240338
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239852
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240338
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240628
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240040
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240658
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240481
# Time to run the bare estimator:  3.1195788383483887 s
# **************************************************
# Timestep 1
# Length of input arrays:  81225
# Time to sort and bin values:  0.0014162063598632812 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4062 elements - Combinations: 8247891
# Bin 4: 4062 elements - Combinations: 8247891
# Bin 5: 4062 elements - Combinations: 8247891
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81225
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128427
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180886
# Bin 3 :Theoretical combinations:  8247891  - When filtered:  8192619
# Bin 4 :Theoretical combinations:  8247891  - When filtered:  8202435
# Bin 5 :Theoretical combinations:  8247891  - When filtered:  8211845
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217059
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226983
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235291
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238116
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239118
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239535
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239983
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239983
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240338
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239850
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240337
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240629
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240040
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240665
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240481
# Time to run the bare estimator:  3.0840110778808594 s
# **************************************************
# Timestep 2
# Length of input arrays:  81223
# Time to sort and bin values:  0.0013833045959472656 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4062 elements - Combinations: 8247891
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81223
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128462
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180909
# Bin 3 :Theoretical combinations:  8247891  - When filtered:  8192631
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198390
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207804
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217068
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226982
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235288
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238116
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239119
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239539
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239984
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239981
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240340
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239851
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240341
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240631
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240040
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240672
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240479
# Time to run the bare estimator:  3.091714859008789 s
# **************************************************
# Timestep 3
# Length of input arrays:  81225
# Time to sort and bin values:  0.0013821125030517578 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4062 elements - Combinations: 8247891
# Bin 4: 4062 elements - Combinations: 8247891
# Bin 5: 4062 elements - Combinations: 8247891
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81225
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128492
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180927
# Bin 3 :Theoretical combinations:  8247891  - When filtered:  8192651
# Bin 4 :Theoretical combinations:  8247891  - When filtered:  8202451
# Bin 5 :Theoretical combinations:  8247891  - When filtered:  8211866
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217075
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226989
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235289
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238117
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239119
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239538
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239983
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239978
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240343
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239852
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240335
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240640
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240040
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240670
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240478
# Time to run the bare estimator:  3.093247175216675 s
# **************************************************
# Timestep 4
# Length of input arrays:  81222
# Time to sort and bin values:  0.0013821125030517578 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81222
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128517
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180944
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188619
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198415
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207823
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217070
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226988
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235289
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238119
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239115
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239539
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239984
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239977
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240338
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239855
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240337
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240643
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240039
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240675
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240477
# Time to run the bare estimator:  3.0875298976898193 s
# **************************************************
# Timestep 5
# Length of input arrays:  81224
# Time to sort and bin values:  0.0014159679412841797 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4062 elements - Combinations: 8247891
# Bin 4: 4062 elements - Combinations: 8247891
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81224
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128546
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180974
# Bin 3 :Theoretical combinations:  8247891  - When filtered:  8192683
# Bin 4 :Theoretical combinations:  8247891  - When filtered:  8202486
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207839
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217088
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8226995
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235287
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238119
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239116
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239545
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239987
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239977
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240341
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239855
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240331
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240649
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240036
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240676
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240475
# Time to run the bare estimator:  3.097738027572632 s
# **************************************************
# Timestep 6
# Length of input arrays:  81222
# Time to sort and bin values:  0.0014164447784423828 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4062 elements - Combinations: 8247891
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81222
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128591
# Bin 2 :Theoretical combinations:  8247891  - When filtered:  8180985
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188648
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198444
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207846
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217095
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227000
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235283
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238120
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239117
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239546
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239988
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239974
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240345
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239853
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240337
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240651
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240033
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240678
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240472
# Time to run the bare estimator:  3.087963581085205 s
# **************************************************
# Timestep 7
# Length of input arrays:  81221
# Time to sort and bin values:  0.0014483928680419922 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81221
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128610
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8176950
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188657
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198457
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207846
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217095
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227008
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235286
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238123
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239118
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239544
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239989
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239977
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240345
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239851
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240339
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240650
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240036
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240679
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240473
# Time to run the bare estimator:  3.0920591354370117 s
# **************************************************
# Timestep 8
# Length of input arrays:  81221
# Time to sort and bin values:  0.0014197826385498047 s
# Bin 1: 4062 elements - Combinations: 8247891
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4061 elements - Combinations: 8243830
# Total elements after binning:  81221
# Bin 1 :Theoretical combinations:  8247891  - When filtered:  8128642
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8176953
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188680
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198486
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207853
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217095
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227010
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235296
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238124
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239119
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239545
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239985
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239973
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240350
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239852
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240342
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240659
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240033
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240683
# Bin 20 :Theoretical combinations:  8243830  - When filtered:  8240469
# Time to run the bare estimator:  3.0834877490997314 s
# **************************************************
# Timestep 9
# Length of input arrays:  81219
# Time to sort and bin values:  0.0013840198516845703 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124631
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8176968
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188696
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198500
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207858
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217101
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227009
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235296
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238130
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239123
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239547
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239984
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239970
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240348
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239859
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240345
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240661
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240030
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240685
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236410
# Time to run the bare estimator:  3.0872788429260254 s
# **************************************************
# Timestep 10
# Length of input arrays:  81219
# Time to sort and bin values:  0.001407623291015625 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124668
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8176995
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188720
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198511
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207871
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217116
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227028
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235306
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238131
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239123
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239552
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239986
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239972
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240353
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239862
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240345
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240664
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240030
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240683
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236408
# Time to run the bare estimator:  3.08901309967041 s
# **************************************************
# Timestep 11
# Length of input arrays:  81219
# Time to sort and bin values:  0.0013892650604248047 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124694
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177021
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188744
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198518
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207870
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217125
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227033
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235310
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238133
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239124
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239556
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239988
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239972
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240356
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239861
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240349
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240669
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240027
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240681
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236407
# Time to run the bare estimator:  3.083899736404419 s
# **************************************************
# Timestep 12
# Length of input arrays:  81219
# Time to sort and bin values:  0.0014328956604003906 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124725
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177042
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188751
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198528
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207876
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217136
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227052
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235311
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238136
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239124
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239560
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239991
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239975
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240356
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239860
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240349
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240666
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240032
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240683
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236408
# Time to run the bare estimator:  3.094426393508911 s
# **************************************************
# Timestep 13
# Length of input arrays:  81219
# Time to sort and bin values:  0.0013995170593261719 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124759
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177062
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188760
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198530
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207882
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217142
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227052
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235317
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238138
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239125
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239563
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239995
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239974
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240358
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239856
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240350
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240668
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240033
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240687
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236410
# Time to run the bare estimator:  3.0855917930603027 s
# **************************************************
# Timestep 14
# Length of input arrays:  81219
# Time to sort and bin values:  0.0014004707336425781 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4061 elements - Combinations: 8243830
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81219
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124793
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177085
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188776
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198540
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207880
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217145
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227055
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235320
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238142
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239129
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239562
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239996
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239976
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240359
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239856
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240346
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240667
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240034
# Bin 19 :Theoretical combinations:  8243830  - When filtered:  8240691
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236410
# Time to run the bare estimator:  3.0875988006591797 s
# **************************************************
# Timestep 15
# Length of input arrays:  81218
# Time to sort and bin values:  0.0014197826385498047 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4061 elements - Combinations: 8243830
# Bin 19: 4060 elements - Combinations: 8239770
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81218
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124833
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177103
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188773
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198554
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207883
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217153
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227061
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235318
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238142
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239130
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239561
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239997
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239979
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240358
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239859
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240346
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240669
# Bin 18 :Theoretical combinations:  8243830  - When filtered:  8240031
# Bin 19 :Theoretical combinations:  8239770  - When filtered:  8236630
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236411
# Time to run the bare estimator:  3.0915584564208984 s
# **************************************************
# Timestep 16
# Length of input arrays:  81217
# Time to sort and bin values:  0.0014033317565917969 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4061 elements - Combinations: 8243830
# Bin 18: 4060 elements - Combinations: 8239770
# Bin 19: 4060 elements - Combinations: 8239770
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81217
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124857
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177121
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188789
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198568
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207901
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217165
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227062
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235319
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238142
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239129
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239564
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239996
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239978
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240363
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239859
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240348
# Bin 17 :Theoretical combinations:  8243830  - When filtered:  8240665
# Bin 18 :Theoretical combinations:  8239770  - When filtered:  8235972
# Bin 19 :Theoretical combinations:  8239770  - When filtered:  8236632
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236410
# Time to run the bare estimator:  3.082862615585327 s
# **************************************************
# Timestep 17
# Length of input arrays:  81215
# Time to sort and bin values:  0.0014350414276123047 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4060 elements - Combinations: 8239770
# Bin 17: 4060 elements - Combinations: 8239770
# Bin 18: 4060 elements - Combinations: 8239770
# Bin 19: 4060 elements - Combinations: 8239770
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81215
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124889
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177155
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188813
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198582
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207905
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217175
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227063
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235323
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238144
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239127
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239562
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239994
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239978
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240363
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239862
# Bin 16 :Theoretical combinations:  8239770  - When filtered:  8236292
# Bin 17 :Theoretical combinations:  8239770  - When filtered:  8236606
# Bin 18 :Theoretical combinations:  8239770  - When filtered:  8235975
# Bin 19 :Theoretical combinations:  8239770  - When filtered:  8236637
# Bin 20 :Theoretical combinations:  8239770  - When filtered:  8236409
# Time to run the bare estimator:  3.090670108795166 s
# **************************************************
# Timestep 18
# Length of input arrays:  81216
# Time to sort and bin values:  0.0013985633850097656 s
# Bin 1: 4061 elements - Combinations: 8243830
# Bin 2: 4061 elements - Combinations: 8243830
# Bin 3: 4061 elements - Combinations: 8243830
# Bin 4: 4061 elements - Combinations: 8243830
# Bin 5: 4061 elements - Combinations: 8243830
# Bin 6: 4061 elements - Combinations: 8243830
# Bin 7: 4061 elements - Combinations: 8243830
# Bin 8: 4061 elements - Combinations: 8243830
# Bin 9: 4061 elements - Combinations: 8243830
# Bin 10: 4061 elements - Combinations: 8243830
# Bin 11: 4061 elements - Combinations: 8243830
# Bin 12: 4061 elements - Combinations: 8243830
# Bin 13: 4061 elements - Combinations: 8243830
# Bin 14: 4061 elements - Combinations: 8243830
# Bin 15: 4061 elements - Combinations: 8243830
# Bin 16: 4061 elements - Combinations: 8243830
# Bin 17: 4060 elements - Combinations: 8239770
# Bin 18: 4060 elements - Combinations: 8239770
# Bin 19: 4060 elements - Combinations: 8239770
# Bin 20: 4060 elements - Combinations: 8239770
# Total elements after binning:  81216
# Bin 1 :Theoretical combinations:  8243830  - When filtered:  8124922
# Bin 2 :Theoretical combinations:  8243830  - When filtered:  8177179
# Bin 3 :Theoretical combinations:  8243830  - When filtered:  8188816
# Bin 4 :Theoretical combinations:  8243830  - When filtered:  8198597
# Bin 5 :Theoretical combinations:  8243830  - When filtered:  8207907
# Bin 6 :Theoretical combinations:  8243830  - When filtered:  8217187
# Bin 7 :Theoretical combinations:  8243830  - When filtered:  8227064
# Bin 8 :Theoretical combinations:  8243830  - When filtered:  8235324
# Bin 9 :Theoretical combinations:  8243830  - When filtered:  8238144
# Bin 10 :Theoretical combinations:  8243830  - When filtered:  8239131
# Bin 11 :Theoretical combinations:  8243830  - When filtered:  8239561
# Bin 12 :Theoretical combinations:  8243830  - When filtered:  8239996
# Bin 13 :Theoretical combinations:  8243830  - When filtered:  8239982
# Bin 14 :Theoretical combinations:  8243830  - When filtered:  8240367
# Bin 15 :Theoretical combinations:  8243830  - When filtered:  8239861
# Bin 16 :Theoretical combinations:  8243830  - When filtered:  8240351
# Bin 17 :Theoretical combinations:  8239770  - When filtered:  8236609
# ...
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138425
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138696
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139097
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139211
# Bin 14 :Theoretical combinations:  8138595  - When filtered:  8135385
# Bin 15 :Theoretical combinations:  8138595  - When filtered:  8134754
# Bin 16 :Theoretical combinations:  8138595  - When filtered:  8135566
# Bin 17 :Theoretical combinations:  8138595  - When filtered:  8135769
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135016
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135988
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135230
# Time to run the bare estimator:  3.0201284885406494 s
# **************************************************
# Timestep 820
# Length of input arrays:  80714
# Time to sort and bin values:  0.0013415813446044922 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4036 elements - Combinations: 8142630
# Bin 15: 4035 elements - Combinations: 8138595
# Bin 16: 4035 elements - Combinations: 8138595
# Bin 17: 4035 elements - Combinations: 8138595
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80714
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034280
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082158
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092428
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101420
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109970
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117958
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127152
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134760
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137383
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138424
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138699
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139097
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139211
# Bin 14 :Theoretical combinations:  8142630  - When filtered:  8139419
# Bin 15 :Theoretical combinations:  8138595  - When filtered:  8134755
# Bin 16 :Theoretical combinations:  8138595  - When filtered:  8135566
# Bin 17 :Theoretical combinations:  8138595  - When filtered:  8135769
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135014
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135988
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135230
# Time to run the bare estimator:  3.0196304321289062 s
# **************************************************
# Timestep 821
# Length of input arrays:  80716
# Time to sort and bin values:  0.0014965534210205078 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4036 elements - Combinations: 8142630
# Bin 15: 4036 elements - Combinations: 8142630
# Bin 16: 4036 elements - Combinations: 8142630
# Bin 17: 4035 elements - Combinations: 8138595
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80716
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034270
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082153
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092421
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101412
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109970
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117959
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127151
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134760
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137382
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138423
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138693
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139095
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139211
# Bin 14 :Theoretical combinations:  8142630  - When filtered:  8139419
# Bin 15 :Theoretical combinations:  8142630  - When filtered:  8138789
# Bin 16 :Theoretical combinations:  8142630  - When filtered:  8139598
# Bin 17 :Theoretical combinations:  8138595  - When filtered:  8135766
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135013
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135986
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135230
# Time to run the bare estimator:  3.0207974910736084 s
# **************************************************
# Timestep 822
# Length of input arrays:  80713
# Time to sort and bin values:  0.0013442039489746094 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4035 elements - Combinations: 8138595
# Bin 15: 4035 elements - Combinations: 8138595
# Bin 16: 4035 elements - Combinations: 8138595
# Bin 17: 4035 elements - Combinations: 8138595
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80713
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034263
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082152
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092420
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101412
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109969
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117958
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127151
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134759
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137382
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138423
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138693
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139095
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139211
# Bin 14 :Theoretical combinations:  8138595  - When filtered:  8135387
# Bin 15 :Theoretical combinations:  8138595  - When filtered:  8134752
# Bin 16 :Theoretical combinations:  8138595  - When filtered:  8135565
# Bin 17 :Theoretical combinations:  8138595  - When filtered:  8135767
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135016
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135990
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135230
# Time to run the bare estimator:  3.020528554916382 s
# **************************************************
# Timestep 823
# Length of input arrays:  80715
# Time to sort and bin values:  0.0014216899871826172 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4036 elements - Combinations: 8142630
# Bin 15: 4036 elements - Combinations: 8142630
# Bin 16: 4035 elements - Combinations: 8138595
# Bin 17: 4035 elements - Combinations: 8138595
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80715
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034258
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082152
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092418
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101412
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109967
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117957
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127151
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134756
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137382
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138423
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138693
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139094
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139211
# Bin 14 :Theoretical combinations:  8142630  - When filtered:  8139422
# Bin 15 :Theoretical combinations:  8142630  - When filtered:  8138788
# Bin 16 :Theoretical combinations:  8138595  - When filtered:  8135564
# Bin 17 :Theoretical combinations:  8138595  - When filtered:  8135767
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135013
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135986
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135232
# Time to run the bare estimator:  3.01979660987854 s
# **************************************************
# Timestep 824
# Length of input arrays:  80717
# Time to sort and bin values:  0.0013887882232666016 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4036 elements - Combinations: 8142630
# Bin 15: 4036 elements - Combinations: 8142630
# Bin 16: 4036 elements - Combinations: 8142630
# Bin 17: 4036 elements - Combinations: 8142630
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80717
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034255
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082153
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092414
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101408
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109957
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117954
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127150
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134756
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137382
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138423
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138693
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139093
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139207
# Bin 14 :Theoretical combinations:  8142630  - When filtered:  8139422
# Bin 15 :Theoretical combinations:  8142630  - When filtered:  8138788
# Bin 16 :Theoretical combinations:  8142630  - When filtered:  8139598
# Bin 17 :Theoretical combinations:  8142630  - When filtered:  8139801
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135012
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135985
# Bin 20 :Theoretical combinations:  8138595  - When filtered:  8135232
# Time to run the bare estimator:  3.0205979347229004 s
# **************************************************
# Timestep 825
# Length of input arrays:  80717
# Time to sort and bin values:  0.001459360122680664 s
# Bin 1: 4036 elements - Combinations: 8142630
# Bin 2: 4036 elements - Combinations: 8142630
# Bin 3: 4036 elements - Combinations: 8142630
# Bin 4: 4036 elements - Combinations: 8142630
# Bin 5: 4036 elements - Combinations: 8142630
# Bin 6: 4036 elements - Combinations: 8142630
# Bin 7: 4036 elements - Combinations: 8142630
# Bin 8: 4036 elements - Combinations: 8142630
# Bin 9: 4036 elements - Combinations: 8142630
# Bin 10: 4036 elements - Combinations: 8142630
# Bin 11: 4036 elements - Combinations: 8142630
# Bin 12: 4036 elements - Combinations: 8142630
# Bin 13: 4036 elements - Combinations: 8142630
# Bin 14: 4036 elements - Combinations: 8142630
# Bin 15: 4036 elements - Combinations: 8142630
# Bin 16: 4036 elements - Combinations: 8142630
# Bin 17: 4036 elements - Combinations: 8142630
# Bin 18: 4035 elements - Combinations: 8138595
# Bin 19: 4035 elements - Combinations: 8138595
# Bin 20: 4035 elements - Combinations: 8138595
# Total elements after binning:  80717
# Bin 1 :Theoretical combinations:  8142630  - When filtered:  8034248
# Bin 2 :Theoretical combinations:  8142630  - When filtered:  8082145
# Bin 3 :Theoretical combinations:  8142630  - When filtered:  8092410
# Bin 4 :Theoretical combinations:  8142630  - When filtered:  8101410
# Bin 5 :Theoretical combinations:  8142630  - When filtered:  8109965
# Bin 6 :Theoretical combinations:  8142630  - When filtered:  8117954
# Bin 7 :Theoretical combinations:  8142630  - When filtered:  8127150
# Bin 8 :Theoretical combinations:  8142630  - When filtered:  8134755
# Bin 9 :Theoretical combinations:  8142630  - When filtered:  8137380
# Bin 10 :Theoretical combinations:  8142630  - When filtered:  8138423
# Bin 11 :Theoretical combinations:  8142630  - When filtered:  8138693
# Bin 12 :Theoretical combinations:  8142630  - When filtered:  8139093
# Bin 13 :Theoretical combinations:  8142630  - When filtered:  8139208
# Bin 14 :Theoretical combinations:  8142630  - When filtered:  8139422
# Bin 15 :Theoretical combinations:  8142630  - When filtered:  8138788
# Bin 16 :Theoretical combinations:  8142630  - When filtered:  8139598
# Bin 17 :Theoretical combinations:  8142630  - When filtered:  8139802
# Bin 18 :Theoretical combinations:  8138595  - When filtered:  8135012
# Bin 19 :Theoretical combinations:  8138595  - When filtered:  8135985

# %%
print(npz_filename)
# Out:
# output/NPARR_SKA_BE_0to2steps_nofilter_bins20_equal_length.npz

# %%
# Load the .npz file
#output_folder = "output/"
#filename = output_folder + npz_filename
#data = np.load('output/' + filename)
data = np.load(npz_filename)

# Access the arrays
bare_estimator_avg = data['bare_estimator_avg']
ell_mean_avg = data['ell_mean_avg']
var_squared_avg = data['var_squared_avg']

# Print the arrays
print("Bare estimator values:", bare_estimator_avg)
print("Ell mean values:", ell_mean_avg)
print("Variance squared values:", var_squared_avg)

# Close the .npz file
data.close()
# Out:
# Bare estimator values: [2.02768503e+04 7.85046041e+02 4.09458242e+02 1.50792124e+02
#  8.81830057e+00 3.74554749e+01 1.03813674e+01 4.01054923e+00
#  1.17624482e+00 1.81529691e-01 3.62512011e-03 2.31163353e-04
#  5.46401907e-06 2.00237225e-08 5.87890903e-10 2.20983054e-17
#  4.20850772e-22 6.97355740e-37 0.00000000e+00 0.00000000e+00]
# Ell mean values: [  555.63287354  1377.57063802  1936.7130127   2443.62695312
#   2956.82356771  3512.10489909  4202.05078125  5206.65983073
#   6838.83626302  8888.67936198 11023.71744792 13086.02539062
#  15848.25683594 18978.46289062 22516.94010417 27559.5
#  31615.04361979 37649.39192708 44252.15755208 50459.9453125 ]
# Variance squared values: [1.54158151e-05 6.00093036e-08 1.14719884e-08 3.81351128e-09
#  1.55673837e-09 6.94908464e-10 3.01620035e-10 1.12334133e-10
#  3.14449358e-11 9.15730744e-12 3.31562974e-12 1.47825737e-12
#  6.05566920e-13 2.60414529e-13 1.16375320e-13 4.52762206e-14
#  2.40551919e-14 1.04113168e-14 4.98666366e-15 2.64416645e-15]
